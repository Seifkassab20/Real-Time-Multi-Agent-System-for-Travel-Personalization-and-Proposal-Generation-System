# %%
import sys
sys.path.append("/Users/maryamsaad/Documents/ASR")

# %%
from ASR.new_src.pipeline import TranscriptionService
default_path = "/Users/maryamsaad/Downloads/New Recording 2.mp3"
    

service = TranscriptionService()
result = service.process_audio(default_path)
print("\n--- Final Corrected Output ---")
print(result.full_corrected_text)
print("------------------------------")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# [Seamless] ✓ Model loaded successfully.
# 2025-12-08 18:45:00,606 - ASR_Pipeline - INFO - Initializing TranscriptionService...
# 2025-12-08 18:45:00,612 - ASR_Pipeline - INFO - TranscriptionService initialized successfully.
# 2025-12-08 18:45:00,613 - ASR_Pipeline - INFO - Processing audio file: /Users/maryamsaad/Downloads/New Recording 2.mp3
# [inference] Starting CHUNKED transcription (lang=arb)...
# [audio] Loading: /Users/maryamsaad/Downloads/New Recording 2.mp3
# [audio] Loaded: torch.Size([1, 5768128]), sr=48000Hz
# [audio] Resampling 48000Hz → 16000Hz...
# [audio] Duration: 120.17s (max: 20.0s)
# [audio] Normalizing amplitude...
# [audio] ✓ Preprocessed: shape=torch.Size([1922710]), range=[-0.991, 1.000]
# [audio] Chunking audio into 20-second segments...
# [audio] Total chunks: 7
# [chunk 1/7] Processing...
# /Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/ASR/new_src/asr_infrence.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   token_ids = torch.tensor(token_ids, dtype=torch.long).unsqueeze(0)
# [chunk 1] Text: مساء الخير شكرا لاتصالك لفندق نايل فيو انا اسمي عائشة ازاي اقدر اساعدك النهاردة هاي عائشة عم نوى اروح رحلة لمصر الشهر الجاي وعايزة احجز اوده في الفندق
# [chunk 1] Avg confidence: 0.739
# [chunk 2/7] Processing...
# [chunk 2] Text: وعايزة احجز اوده في اوتيل برضو عايزه اعرف ايه ال Activities اللي اقدر اعملها وانا قاعدة في الفترة بتاعتي طبعا اقدر اساعدك ف اعرف هتسافري امتى طبعا انا مسافرة 14 يناير وقاعدة لحد 21 يناير حلوه اوي
# [chunk 2] Avg confidence: 0.726
# [chunk 3/7] Processing...
# [chunk 3] Text: حلوة اوي التواريخ دي عندي كذا اودة فاضية عايزه اودة ستاندرد ولا اودة ديلكس وفيها نايل فيو ولا عايزه سويت
# [chunk 3] Avg confidence: 0.655
# [chunk 4/7] Processing...
# [chunk 4] Text: بيبقى فيها بريكفاست و واي فاي و فري ايربورت بيك اب و اكسيس روف توب و بالكونة ببانوراميك فيو عن نيل عايزاني احجزلك الروم دي ايوة طبعا برضو عايزة اعرف ايه ال Activities اللي موجودين
# [chunk 4] Avg confidence: 0.674
# [chunk 5/7] Processing...
# [chunk 5] Text: عايزة اعرف ايه ال Activities اللي موجودة قريب مني حلو بما اني كنت بيقعد في القاهرة في ال Popular Activities دي في اي حاجة فيهم ب Interest You Of course طبعا بفكر اروح ال Giza Tour و Nine Dinner Cruise ازاي اقدر احجزهم
# [chunk 5] Avg confidence: 0.710
# [chunk 6/7] Processing...
# [chunk 6] Text: ازاي اقدر احجزهم اقدر اجهزهم لك دلوقتي عايزة تواريخ ايه خلينا نروح الجيزة وبعدين الدينر كروز اوكي حلوة اوي ماشي هستناكي في مطار القاهرة امتى اليوم اللي هتيجي فيه هاجي يوم اخر
# [chunk 6] Avg confidence: 0.739
# [chunk 7/7] Processing...
# [chunk 7] Text: هاجي يوم 14 واحد الساعة 6 هنتظرك هناك حلوة أوي شكرا للمساعدة
# [chunk 7] Avg confidence: 0.666
# 2025-12-08 18:46:07,022 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# 2025-12-08 18:46:33,885 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# 2025-12-08 18:46:54,735 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# 2025-12-08 18:46:58,508 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# 2025-12-08 18:47:02,315 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# 2025-12-08 18:47:23,105 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# 2025-12-08 18:47:24,950 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# 2025-12-08 18:47:24,952 - ASR_Pipeline - INFO - Audio processing completed successfully.
# --- Final Corrected Output ---
# مساء الخير. شكرا لاتصالك لفندق نايل فيو. أنا اسمي عائشة. إزاي أقدر أساعدك النهاردة؟ هاي عائشة. عايزة أروح رحلة لمصر الشهر الجاي وعايزة أحجز أودية في الفندق. وعايزة احجز أوضة في أوتيل برضو. عايزة أعرف إيه الـactivities اللي أقدر أعملها وأنا قاعدة في الفترة بتاعتي. طبعًا أقدر أساعدك. فهتسافري إمتى؟ طبعًا أنا مسافرة 14 يناير وقاعدة لحد 21 يناير. حلوة أوي. حلوة اوي التواريخ دي، عندي كذا اودة فاضية. عايزة اودة ستاندرد ولا اودة ديلكس وفيها نايل فيو؟ ولا عايزة سويت؟ بيبقى فيها بريكفاست وواي فاي وفري ايربورت بيك اب واكسيس روف توب وبالكونة ببانوراميك فيو عن النيل. عايزاني احجزلك الروم دي؟ ايوة طبعا. برضو عايزة اعرف ايه الactivities اللي موجودين. عايزة اعرف ايه ال activities اللي موجودة قريب مني. بما اني مقعدة في القاهرة، في popular activities دي. في اي حاجة فيهم بيثير اهتمامك؟ Of course طبعا بفكر اروح Giza Tour و Nile Dinner Cruise. ازاي اقدر احجزهم؟ ازاي اقدر احجزهم؟ اقدر اجهزهم لك دلوقتي. عايزة تواريخ ايه؟ خلينا نروح الجيزة وبعدين الدينر كروز. أوكي، حلوة أوي. ماشي، هستناكي في مطار القاهرة امتى؟ اليوم اللي هتيجي فيه هاجي يوم اخر. هاجي يوم 14 الساعة 6 هنتظرك هناك. الحلوة أوي. شكراً للمساعدة.
# ------------------------------

# %%
corrected=result.full_raw_text

# %%
import re

def add_newlines(text):
    # Add newline after . or ? if not already followed by one
    text = re.sub(r'([.?])\s*', r'\1\n', text)
    return text.strip()
corrected = result.full_corrected_text   # or whatever your field is
formatted = add_newlines(corrected)
print(formatted.replace(".",""))
# Out:
# مساء الخير
# شكرا لاتصالك لفندق نايل فيو
# أنا اسمي عائشة
# إزاي أقدر أساعدك النهاردة؟ هاي عائشة
# عايزة أروح رحلة لمصر الشهر الجاي وعايزة أحجز أودية في الفندق
# وعايزة احجز أوضة في أوتيل برضو
# عايزة أعرف إيه الـactivities اللي أقدر أعملها وأنا قاعدة في الفترة بتاعتي
# طبعًا أقدر أساعدك
# فهتسافري إمتى؟ طبعًا أنا مسافرة 14 يناير وقاعدة لحد 21 يناير
# حلوة أوي
# حلوة اوي التواريخ دي، عندي كذا اودة فاضية
# عايزة اودة ستاندرد ولا اودة ديلكس وفيها نايل فيو؟ ولا عايزة سويت؟ بيبقى فيها بريكفاست وواي فاي وفري ايربورت بيك اب واكسيس روف توب وبالكونة ببانوراميك فيو عن النيل
# عايزاني احجزلك الروم دي؟ ايوة طبعا
# برضو عايزة اعرف ايه الactivities اللي موجودين
# عايزة اعرف ايه ال activities اللي موجودة قريب مني
# بما اني مقعدة في القاهرة، في popular activities دي
# في اي حاجة فيهم بيثير اهتمامك؟ Of course طبعا بفكر اروح Giza Tour و Nile Dinner Cruise
# ازاي اقدر احجزهم؟ ازاي اقدر احجزهم؟ اقدر اجهزهم لك دلوقتي
# عايزة تواريخ ايه؟ خلينا نروح الجيزة وبعدين الدينر كروز
# أوكي، حلوة أوي
# ماشي، هستناكي في مطار القاهرة امتى؟ اليوم اللي هتيجي فيه هاجي يوم اخر
# هاجي يوم 14 الساعة 6 هنتظرك هناك
# الحلوة أوي
# شكراً للمساعدة

# %%
from extraction_agent.agent import ExtractionAgent
from extraction_agent.models import TranscriptSegment
from datetime import datetime
import time
import json
import uuid
from collections import defaultdict

agent = ExtractionAgent()
results = []
aggregated_entities = defaultdict(list)
total_start = time.time()

# Split text into sentences
corrected = formatted.replace(".", "")
sentences = [s.strip() for s in corrected.split('\n') if s.strip()]

# Process each sentence as a segment
for i, text in enumerate(sentences):
    segment = TranscriptSegment(
        segment_id=f"seg_{i:03d}",
        timestamp=datetime.now(),
        speaker="customer",
        text=text
    )
    extraction = await agent._extract(segment)
    entities = extraction.entities
    print(f"\nSegment {i+1}: {text[:50]}...")
    print(f"Entities: {json.dumps(entities, indent=2)}")
    results.append(entities)
    
    # Aggregate entities
    for key, value in entities.items():
        if isinstance(value, list):
            aggregated_entities[key].extend(value)
        elif isinstance(value, dict):
            aggregated_entities[key].append(value)
        else:
            aggregated_entities[key].append(value)

total_time = (time.time() - total_start) * 1000
print(f"\nTotal processing time: {total_time:.2f}ms")
print(f"Average per segment: {total_time/len(sentences):.2f}ms")

print("\n--- Aggregated Entities ---")
print(json.dumps(aggregated_entities, indent=2))
# Out:
# [extractor_b9fb62] Extraction Agent ready
# 2025-12-08 18:47:26,273 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {}
# ```
#   ✓ Extracted in 1240ms
#
# Segment 1: مساء الخير...
# Entities: {}
# 2025-12-08 18:47:27,007 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {}
# ```
#   ✓ Extracted in 733ms
#
# Segment 2: شكرا لاتصالك لفندق نايل فيو...
# Entities: {}
# 2025-12-08 18:47:27,773 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {}
# ```
#   ✓ Extracted in 765ms
#
# Segment 3: أنا اسمي عائشة...
# Entities: {}
# 2025-12-08 18:47:28,398 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {}
# ```
#   ✓ Extracted in 627ms
#
# Segment 4: إزاي أقدر أساعدك النهاردة؟ هاي عائشة...
# Entities: {}
# 2025-12-08 18:47:29,200 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": ["الشهر الجاي"],
#   "locations": ["مصر"],
#   "activities": ["رحلة"],
#   "preferences": {
#     "hotel_type": ["فندق"],
#     "specific_location": ["أودية"]
#   },
#   "tone": "hesitant/excited"
# }
# ```
#   ✓ Extracted in 800ms
#
# Segment 5: عايزة أروح رحلة لمصر الشهر الجاي وعايزة أحجز أودية...
# Entities: {}
# 2025-12-08 18:47:29,905 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "locations": ["برضو"],
#   "activities": ["احجز أوضة"],
#   "preferences": ["أوتيل"]
# }
# ```
#   ✓ Extracted in 705ms
#
# Segment 6: وعايزة احجز أوضة في أوتيل برضو...
# Entities: {}
# 2025-12-08 18:47:30,701 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [],
#   "activities": ["activities"],
#   "preferences": {},
#   "keywords": ["activities", "فترة", "قاعدة"],
#   "tone": "hesitant/expectant"
# }
# ```
#   ✓ Extracted in 796ms
#
# Segment 7: عايزة أعرف إيه الـactivities اللي أقدر أعملها وأنا...
# Entities: {}
# 2025-12-08 18:47:31,264 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: {}
# ```json
# {}
# ```
#   ✓ Extracted in 564ms
#
# Segment 8: طبعًا أقدر أساعدك...
# Entities: {}
# 2025-12-08 18:47:32,028 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": ["14 يناير", "21 يناير"],
#   "locations": [],
#   "activities": [],
#   "preferences": [],
#   "keywords": ["سافري", "مسافرة"],
#   "tone": "hesitant/expectant"
# }
# ```
#   ✓ Extracted in 765ms
#
# Segment 9: فهتسافري إمتى؟ طبعًا أنا مسافرة 14 يناير وقاعدة لح...
# Entities: {}
# 2025-12-08 18:47:32,614 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 584ms
#
# Segment 10: حلوة أوي...
# Entities: {}
# 2025-12-08 18:47:33,325 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {}
# ```
#   ✓ Extracted in 712ms
#
# Segment 11: حلوة اوي التواريخ دي، عندي كذا اودة فاضية...
# Entities: {}
# 2025-12-08 18:47:34,844 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": [],
#   "budget": {
#     "preferred": ["standard"],
#     "range": ["deluxe"]
#   },
#   "travelers": {
#     "count": 1,
#     "age": null
#   },
#   "locations": [
#     "نيل"  // Nile (likely Egypt, Nile River area)
#   ],
#   "activities": [],
#   "preferences": {
#     "hotel_type": ["standard", "deluxe"],
#     "amenities": ["breakfast", "WiFi", "free airport pickup", "accessibility features (e.g., wheelchair, panoramic view of the Nile)"]
#   },
#   "keywords": ["nailev", "sweet", "breakfast", "WiFi", "free airport pickup", "accessibility", "panoramic view"],
#   "tone": "enthusiastic, specific, and eager"
# }
# ```
#   ✓ Extracted in 1518ms
#
# Segment 12: عايزة اودة ستاندرد ولا اودة ديلكس وفيها نايل فيو؟ ...
# Entities: {}
# 2025-12-08 18:47:35,411 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {}
# ```
#   ✓ Extracted in 568ms
#
# Segment 13: عايزاني احجزلك الروم دي؟ ايوة طبعا...
# Entities: {}
# 2025-12-08 18:47:35,982 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "activities": ["activities"]
# }
# ```
#   ✓ Extracted in 569ms
#
# Segment 14: برضو عايزة اعرف ايه الactivities اللي موجودين...
# Entities: {}
# 2025-12-08 18:47:36,727 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "locations": ["قريب مني"],
#   "activities": ["activities"],
#   "tone": "hesitant"
# }
# ```
#   ✓ Extracted in 745ms
#
# Segment 15: عايزة اعرف ايه ال activities اللي موجودة قريب مني...
# Entities: {}
# 2025-12-08 18:47:37,506 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": ["Cairo (القاهرة)"],
#   "activities": ["popular activities"],
#   "preferences": {},
#   "keywords": ["Cairo", "popular activities"],
#   "tone": "neutral"
# }
# ```
#   ✓ Extracted in 781ms
#
# Segment 16: بما اني مقعدة في القاهرة، في popular activities دي...
# Entities: {}
# 2025-12-08 18:47:38,606 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [
#     {
#       "country": "Egypt",
#       "city": "Giza",
#       "site": "Giza Pyramids"
#     },
#     {
#       "country": "Egypt",
#       "activity_type": "Dinner Cruise",
#       "location": "Nile River"
#     }
#   ],
#   "activities": [
#     {
#       "type": "Tour",
#       "location": "Giza"
#     },
#     {
#       "type": "Dinner Cruise",
#       "location": "Nile River"
#     }
#   ],
#   "preferences": {},
#   "keywords": ["Giza Tour", "Nile Dinner Cruise"],
#   "tone": "enthusiastic"
# }
# ```
#   ✓ Extracted in 1099ms
#
# Segment 17: في اي حاجة فيهم بيثير اهتمامك؟ Of course طبعا بفكر...
# Entities: {}
# 2025-12-08 18:47:39,439 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "locations": [],
#   "activities": [],
#   "preferences": [],
#   "dates": [],
#   "budget": [],
#   "travelers": [],
#   "keywords": ["احجزهم", "احجز", "اجهزهم", "للك", "دلوقتي"],
#   "tone": "hesitant, urgent"
# }
# ```
#   ✓ Extracted in 833ms
#
# Segment 18: ازاي اقدر احجزهم؟ ازاي اقدر احجزهم؟ اقدر اجهزهم لك...
# Entities: {}
# 2025-12-08 18:47:40,239 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": ["جيزة", "الدينار كروز"],
#   "locations": ["الجيزة", "الدينار كروز"],
#   "activities": ["الدينار كروز"],
#   "tone": "hesitant/excited"
# }
# ```
#   ✓ Extracted in 800ms
#
# Segment 19: عايزة تواريخ ايه؟ خلينا نروح الجيزة وبعدين الدينر ...
# Entities: {}
# 2025-12-08 18:47:40,842 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 603ms
#
# Segment 20: أوكي، حلوة أوي...
# Entities: {}
# 2025-12-08 18:47:41,645 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": ["اليوم اللي هتيجي فيه", "يوم آخر"],
#   "locations": ["مطار القاهرة"],
#   "keywords": ["مطار", "قاهرة"]
# }
# ```
#   ✓ Extracted in 802ms
#
# Segment 21: ماشي، هستناكي في مطار القاهرة امتى؟ اليوم اللي هتي...
# Entities: {}
# 2025-12-08 18:47:47,468 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {
#   "dates": ["14"],
#   "locations": ["هناك"],
#   "keywords": ["هاجي", "يوم", "ساعة", "هنتظرك"]
# }
# ```
#   ✓ Extracted in 5823ms
#
# Segment 22: هاجي يوم 14 الساعة 6 هنتظرك هناك...
# Entities: {}
# 2025-12-08 18:47:48,170 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# ❌ Failed to parse LLM output: ```json
# {}
# ```
#   ✓ Extracted in 702ms
#
# Segment 23: الحلوة أوي...
# Entities: {}
# 2025-12-08 18:47:48,771 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in
ة امتى؟ اليوم اللي هتيجوا فيه؟ هاجي يوم التاني. هيجي يوم 14 الواحد الساعة 6. هنتظرك هناك. حلوة أوي. شكراً للمساعدة.', segments=[TranscriptionSegment(raw_text='مساء الخير شكرا لاتصالك لفندق نايل فيو انا اسمي عائشة ازاي اقدر اساعدك النهاردة هاي عائشة عم نوى اروح رحلة لمصر الشهر الجاي وعايزة احجز اوده في الفندق', corrected_text='مساء الخير، شكراً لاتصالك لفندق نايل فيو. أنا اسمي عائشة، ازاي أقدر اساعدك النهاردة؟ هاي عائشة، أنا نوى عايزة أروح رحلة لمصر الشهر الجاي، وعايزة احجز أودة في الفندق.', confidence=0.7387433366342024, start_time=None, end_time=None, needs_review=False), TranscriptionSegment(raw_text='وعايزة احجز اوده في اوتيل برضو عايزه اعرف ايه ال Activities اللي اقدر اعملها وانا قاعدة في الفترة بتاعتي طبعا اقدر اساعدك ف اعرف هتسافري امتى طبعا انا مسافرة 14 يناير وقاعدة لحد 21 يناير حلوه اوي', corrected_text='وعايزة احجز أودة في أوتيل برضو. عايزة اعرف إيه الـactivities اللي أقدر أعملها وأنا قاعدة في الفترة بتاعتي. طبعا أقدر أساعدك في ده. هتسافري امتى؟ طبعا أنا مسافرة 14 يناير وقاعدة لحد 21 يناير. حلوة أوي.', confidence=0.7259778734799978, start_time=None, end_time=None, needs_review=False), TranscriptionSegment(raw_text='حلوة اوي التواريخ دي عندي كذا اودة فاضية عايزه اودة ستاندرد ولا اودة ديلكس وفيها نايل فيو ولا عايزه سويت', corrected_text='حلوة أوي التواريخ دي، عندي كذا أوضة فاضية. عايزة أوضة ستاندرد ولا أوضة ديلكس وفيها نايل فيو؟ ولا عايزة سويت؟', confidence=0.6547385537347128, start_time=None, end_time=None, needs_review=True), TranscriptionSegment(raw_text='بيبقى فيها بريكفاست و واي فاي و فري ايربورت بيك اب و اكسيس روف توب و بالكونة ببانوراميك فيو عن نيل عايزاني احجزلك الروم دي ايوة طبعا برضو عايزة اعرف ايه ال Activities اللي موجودين', corrected_text='بيبقى فيها بريكفاست وواي فاي وفري ايربورت بيك اب وإكسيس روف توب وبالكونة ببانوراميك فيو على النيل. عايزاني احجزلك الروم دي؟ أيوة طبعا. برضو عايزة أعرف ايه الـactivities ا ...

# %%
segment
# Out:
# TranscriptSegment(segment_id='seg_021', timestamp=datetime.datetime(2025, 12, 8, 18, 34, 42, 555746), speaker='customer', text='شكراً للمساعدة')

# %%
# from jiwer import wer, cer
# import os
# import json
# import numpy as np



# def load_transcript(path):
#     with open(path, "r", encoding="utf-8") as f:
#         lines = f.readlines()

#     texts = []
#     for line in lines:
#         if not line.strip():
#             continue

#         # transcripts are like:
#         # [0.170,1.120]   G0348   female    الو السلام عليكم
#         parts = line.split("\t")
#         text = parts[-1].strip()

#         # skip tags like [NPS], [ENS]
#         if text.startswith("[") and text.endswith("]"):
#             continue

#         texts.append(text)

#     # merge all segments into one reference
#     return " ".join(texts)

و بصراحة يعني عشان بلحقش همَ ثلث شهور أجازة الصيف وبرجع ما بسجلش هناك في أندية فماعنديش يعني صحاب كثير فممكن ألعب مثلاً مع خالي مع عمي لو لاقيت صحاب هناك بلعب معاهم بروح نادي كدا يعني هنا الصراحة يعني عندي صحاب آه في المدرسة آه وبلعب معاهم آه صح يعني مثلاً آه لما يكون لما مثلاً أنتِ تختطي لمباراة مثلاً عندك مباراة صعبة أنتِ لازم ترتبي ترتيب اللاعبين بطريقة صح خط الدفاع وخط ال آه الوسط والهجوم لازم ترتيبهم بالطريقة الصح وتحطيلهم طريقة هجومية لأي ظرف اللاعب أخذ منهم الكرة ازاي يتصرفوا كدا يعني وعاوزة ذكاء وسرعة كمان سرعة بديهة يعني لما مثلاً تجيله الكرة مش لسا تفكري هتدوديها لمين لازم يكون عندك سرعة بديهة تاخذيها من هنا ترميها على طول لل آه للي أنت شايفاه أنه أنسب واحد تديه الكرة طبعاً العامل الأول والأخير على المدرب نفسه لأن مثلاً زي ما يقلك آه وراء كل فريق ناجح مدرب ناجح حاجة زي كذا يعني فهو إذا كان مدرب ناجح وعرف يخطط ازاي فريقه هيمشي على نفس خطواته وفريقه هيكتسب الخبرة منه لا يعني كذا ممكن ان اتعلم شوية مهارات من على النت وأفضل أعملها مرة وإثنين وثلاثة وعشرة لغاية ما أتقنها وأتقنها بقى وبعدين أجربها مع صحابي مع المدرب مع مع أي حد المهم ان انا اجربها ولو نجحت فيها بروح على المهارة اللي بعدها آه كانت حصة رياضة آه مرتين في الأسبوع كده آه بتلعبي كرة يعني الأولاد لهم أي لعبة يختاروها والبنات نفس الحكاية بس غالباً يعني كنا دائماً بنلعب كرة أحنا الأولاد وكان أحياناً بنعمل دوريات في المدرسة يجي المدير مثلاً يقلنا هنعمل دوري كرة وفرق ونهائي يعني كدا يعني لا الصراحة لأ ما جالتليش فرصة اشارك فيها لأ فصل مع فصل يعني مثلاً همَ اللي كانوا بيلعبوا صف آه خامس وسادس ورابع تقريباً شوية يعني كذا من الرابع صراحة لسا مش مقرر كويس قوي أه كنت بقول ممكن مثلاً ألعب كرة سنتين بس وبعدين بقى نعم لأ لما أكبر أدخل نادي وألعب سنتين وبعدين أطلع أشوف هشوف أبقى دكتور عالم أه بحب التاكوندو والكراتيه يعني كنت كذا بلعبهم فترة لا الكراتي كنت بلعبها شوية لأ الكونغفوا ما جربتوش قبل كذا هو أولاً على شان تقدري تلعبي ك ...

# %%
# import jiwer
# from pyarabic.araby import strip_tashkeel, strip_tatweel, normalize_hamza

# def normalize_arabic(text):
#     text = text.replace("أ","ا").replace("إ","ا").replace("آ","ا")
#     text = strip_tashkeel(text)
#     text = strip_tatweel(text)
#     text = normalize_hamza(text)
#     return text

# gt = normalize_arabic(gt)
# output = normalize_arabic(output)
# wer_value = jiwer.wer(gt, output)
# cer_value = jiwer.cer(gt, output)
# print(f"WER: {wer_value:.2%}")
# print(f"CER: {cer_value:.2%}")
# Out:
# WER: 95.15%
# CER: 70.31%
