# %%
import sys
sys.path.append("/Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/backend")

# %%
from backend.core.ASR.src.pipeline import TranscriptionService
default_path = "/Users/maryamsaad/Documents/ASR/trial.wav"
    

service = TranscriptionService()
result = service.process_audio(default_path)
# Out:
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-12-19 13:07:33,196 - ASR_Pipeline - INFO - Initializing TranscriptionService...
# 2025-12-19 13:07:33,197 - backend.core.tracing_config - INFO - LangSmith tracing configured successfully. Project: asr-pipeline-tracing, Endpoint: https://api.smith.langchain.com
# 2025-12-19 13:07:33,197 - ASR_Pipeline - INFO - LangSmith tracing configured successfully
# 2025-12-19 13:07:33,229 - llm - INFO - Ollama service check metadata: {'service_name': 'ollama', 'host': 'http://localhost:11434', 'connection_timestamp': '2025-12-19 13:07:33', 'protocol': 'http', 'hostname': 'localhost', 'port': 11434, 'path': '', 'health_check_url': 'http://localhost:11434/api/tags', 'http_status_code': 200, 'service_available': True, 'response_time_ms': 31.428, 'available_models': ['gpt-oss:120b-cloud', 'qwen3-vl:235b-instruct-cloud', 'deepseek-v3.1:671b-cloud', 'qwen3-vl:235b-cloud', 'ministral-3:3b'], 'model_count': 5, 'expected_model': 'ministral-3:3b', 'api_key_configured': True, 'initialization_context': 'llm_engine_init', 'connection_successful': True}
# 2025-12-19 13:07:33,234 - llm - INFO - LLMEngine initialization metadata: {'component': 'llm_engine_init', 'project': 'asr-pipeline-tracing', 'tracing_enabled': True, 'ollama_host': 'http://localhost:11434', 'correction_model': 'ministral-3:3b', 'api_key_configured': True, 'client_initialized': True, 'parser_initialized': True, 'prompt_template_loaded': True, 'ollama_service_available': True, 'ollama_connection_time_ms': 31.428, 'initialization_time_seconds': 0.037, 'initialization_timestamp': '2025-12-19 13:07:33', 'engine_status': 'initialized_successfully'}
# 2025-12-19 13:07:33,234 - ASR_Pipeline - INFO - TranscriptionService initialization metadata: {'component': 'transcription_service_init', 'project': 'asr-pipeline-tracing', 'tracing_enabled': True, 'environment_variables': {'LANGSMITH_TRACING_V2': 'true', 'LANGSMITH_PROJECT': 'asr-pipeline-tracing', 'LANGSMITH_API_KEY': '***', 'DEVICE': 'mps', 'MODEL_NAME': 'facebook/seamless-m4t-v2-large', 'CORRECTION_MODEL': 'ministral-3:3b', 'OLLAMA_HOST': 'http://localhost:11434', 'CHUNK_LENGTH': '20.0', 'OVERLAP': '2.0'}, 'tracing_setup_successful': True, 'correction_engine_initialized': True, 'initialization_time_seconds': 0.038, 'initialization_timestamp': '2025-12-19 13:07:33', 'service_status': 'initialized_successfully'}
# 2025-12-19 13:07:33,235 - ASR_Pipeline - INFO - TranscriptionService initialized successfully.
# 2025-12-19 13:07:33,236 - ASR_Pipeline - INFO - File operation metadata: {'file_path': '/Users/maryamsaad/Documents/ASR/trial.wav', 'operation_type': 'audio_file_validation', 'operation_timestamp': '2025-12-19 13:07:33', 'file_exists': True, 'file_size_bytes': 18581454, 'file_size_mb': 17.721, 'is_file': True, 'is_directory': False, 'last_modified': '2025-11-28 22:24:52', 'creation_time': '2025-11-28 22:24:53', 'readable': True, 'writable': True, 'executable': False, 'file_mode': '0o100644', 'expected_file_type': 'audio', 'processing_context': 'asr_pipeline', 'operation_time_ms': 0.43, 'operation_successful': True}
# 2025-12-19 13:07:33,237 - ASR_Pipeline - WARNING - Could not calculate audio duration: No module named 'ASR'
# 2025-12-19 13:07:33,237 - ASR_Pipeline - INFO - Processing audio file: /Users/maryamsaad/Documents/ASR/trial.wav
# 2025-12-19 13:07:33,237 - ASR_Pipeline - INFO - Pipeline tracing metadata: {'component': 'asr_pipeline', 'project': 'asr-pipeline-tracing', 'tracing_enabled': True, 'audio_file': '/Users/maryamsaad/Documents/ASR/trial.wav', 'file_size_mb': 17.72, 'duration_seconds': None, 'processing_start_time': '2025-12-19 13:07:33', 'target_language': 'arb'}
# [Seamless] ✓ Model loaded successfully in 14.316s.
# http://localhost:11434
# f1f1b3b476804e1fa0dec1fd5614f6ad.3Kbx433VLB3s1Bq-BfSR93FD
# ministral-3:3b
#
# [inference] Starting CHUNKED transcription (lang=arb)...
# [audio] Loading: /Users/maryamsaad/Documents/ASR/trial.wav
# [audio] Loaded: torch.Size([1, 9290688]), sr=48000Hz
# [audio] Resampling 48000Hz → 16000Hz...
# [audio] Duration: 193.56s (max: 20.0s)
# [audio] Normalizing amplitude...
# [audio] ✓ Preprocessed: shape=torch.Size([3096896]), range=[-1.000, 0.828]
# [audio] Chunking audio into 20-second segments...
# [audio] Total chunks: 11
# [chunk 1/11] Processing...
# 2025-12-19 13:07:34,091 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# /Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/backend/core/ASR/src/asr_infrence.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   token_ids = torch.tensor(token_ids, dtype=torch.long).unsqueeze(0)
# [chunk 1] Text: مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر
# [chunk 1] Avg confidence: 0.741
# [cleanup] MPS cache cleared for chunk 1: True
# [chunk 2/11] Processing...
# 2025-12-19 13:07:37,959 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [chunk 2] Text: ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي
# [chunk 2] Avg confidence: 0.737
# [cleanup] MPS cache cleared for chunk 2: True
# [chunk 3/11] Processing...
# 2025-12-19 13:07:39,403 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [chunk 3] Text: يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة
# [chunk 3] Avg confidence: 0.772
# [cleanup] MPS cache cleared for chunk 3: True
# [chunk 4/11] Processing...
# 2025-12-19 13:07:41,303 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [chunk 4] Text: كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية
# [chunk 4] Avg confidence: 0.752
# [cleanup] MPS cache cleared for chunk 4: True
# [chunk 5/11] Processing...
# 2025-12-19 13:07:44,056 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [chunk 5] Text: وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل
# [chunk 5] Avg confidence: 0.745
# [cleanup] MPS cache cleared for chunk 5: True
# [chunk 6/11] Processing...
# [chunk 6] Text: تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة
# [chunk 6] Avg confidence: 0.719
# [cleanup] MPS cache cleared for chunk 6: True
# [chunk 7/11] Processing...
# 2025-12-19 13:07:47,812 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [chunk 7] Text: جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي
# [chunk 7] Avg confidence: 0.715
# [cleanup] MPS cache cleared for chunk 7: True
# [chunk 8/11] Processing...
# 2025-12-19 13:07:49,060 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [chunk 8] Text: لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته
# [chunk 8] Avg confidence: 0.690
# [cleanup] MPS cache cleared for chunk 8: True
# [chunk 9/11] Processing...
# 2025-12-19 13:07:50,748 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:07:52,454 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [chunk 9] Text: تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز
# [chunk 9] Avg confidence: 0.737
# [cleanup] MPS cache cleared for chunk 9: True
# [chunk 10/11] Processing...
# [chunk 10] Text: هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون
# [chunk 10] Avg confidence: 0.680
# [cleanup] MPS cache cleared for chunk 10: True
# [chunk 11/11] Processing...
# [chunk 11] Text: أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة
# [chunk 11] Avg confidence: 0.738
# [cleanup] MPS cache cleared for chunk 11: True
# 2025-12-19 13:07:56,274 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:07:58,057 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:07:59,505 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر' corrected_text='مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر. اه الحقيقة انا بفكر ازور مصر!' confidence=0.7409221651879224 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:00,624 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:02,307 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي' corrected_text='ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا و سهلا يا أستاذ جون شرفتنا؟ قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي، انا ناوي اقعد حوالي خمسة ليالي.' confidence=0.7367354713637253 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:03,113 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:04,961 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة' corrected_text='يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة' confidence=0.7717744274572893 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:05,783 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:08,018 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية' corrected_text='كنت بفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنايت لايف شوية. نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها. برضه عايزة ازور أماكن سياحية!' confidence=0.7518013874689738 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:08,832 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:10,572 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل' corrected_text='وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، مثل القاهرة فعلا غنية بالحاجات دي. ممكن نزور الأهرامات، المتحف المصري، خان الخليلي، وكمان نرتبلك خروجات ليلية حلوة على النيل!' confidence=0.7454255505612022 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:11,384 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:13,698 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة' corrected_text='تحبي يكون البرنامج موزع بين سياحة الصبح ونايت لايف بالليل، اه بالظبط ده اللي أنا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس نخليه رايح مثلا جولة نيلية أو حاجة هائلة!' confidence=0.7186777591705322 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:14,532 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:16,354 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي' corrected_text='جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة. حابب نشتغل عليها يعني، متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم. لو تسمح لي' confidence=0.714698489119367 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:17,495 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:19,252 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته' corrected_text='لو ترضي لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقم هو 1202550198. ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته!' confidence=0.6904925065381187 start_time=None end_time=None needs_review=True
# 2025-12-19 13:08:20,420 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:22,002 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز' corrected_text='تمام سجلتِك آخر حاجة، حضرتك جاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز، هجهز!' confidence=0.7365610212087631 start_time=None end_time=None needs_review=False
# 2025-12-19 13:08:22,843 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:24,820 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون' corrected_text='هذا الفيديو ممتاز، هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل. تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح. العفو يا أستاذ جون!' confidence=0.680328263176812 start_time=None end_time=None needs_review=True
# 2025-12-19 13:08:25,585 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:27,027 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-19 13:08:27,148 - ASR_Pipeline - INFO - Final cleanup metadata: {'cleanup_type': 'general_memory', 'cleanup_timestamp': '2025-12-19 13:08:27', 'resource_details': {'cleanup_trigger': 'pipeline_completion', 'processed_chunks': 11, 'processing_duration': 53.798125982284546}, 'garbage_collected': True, 'objects_collected': 1145, 'cleanup_method': 'gc.collect()', 'processing_context': 'asr_pipeline_completion', 'cleanup_time_ms': 114.456, 'cleanup_successful': True}
# 2025-12-19 13:08:27,149 - ASR_Pipeline - INFO - Audio processing completed successfully.
# SEGMENT  raw_text='أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة' corrected_text='استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!' confidence=0.7378794727502046 start_time=None end_time=None needs_review=False

# %%
for segment in result:
    print(segment.corrected_text)
# Out:
# مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر. اه الحقيقة انا بفكر ازور مصر!
# ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا و سهلا يا أستاذ جون شرفتنا؟ قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي، انا ناوي اقعد حوالي خمسة ليالي.
# يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة
# كنت بفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنايت لايف شوية. نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها. برضه عايزة ازور أماكن سياحية!
# وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، مثل القاهرة فعلا غنية بالحاجات دي. ممكن نزور الأهرامات، المتحف المصري، خان الخليلي، وكمان نرتبلك خروجات ليلية حلوة على النيل!
# تحبي يكون البرنامج موزع بين سياحة الصبح ونايت لايف بالليل، اه بالظبط ده اللي أنا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس نخليه رايح مثلا جولة نيلية أو حاجة هائلة!
# جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة. حابب نشتغل عليها يعني، متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم. لو تسمح لي
# لو ترضي لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقم هو 1202550198. ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته!
# تمام سجلتِك آخر حاجة، حضرتك جاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز، هجهز!
# هذا الفيديو ممتاز، هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل. تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح. العفو يا أستاذ جون!
# استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!

# %%
from backend.core.ASR.src.pipeline import TranscriptionService
from backend.core.extraction_agent.extraction_agent import ExtractionAgent
from backend.core.extraction_agent.models import TranscriptSegment, Agent_output
from datetime import datetime
import time

from collections import defaultdict

agent = ExtractionAgent()
results = []
aggregated_entities = defaultdict(list)
total_start = time.time()


# Process each sentence as a segment
for i, segment in enumerate(result):
    segment = TranscriptSegment(
        segment_id=f"seg_{i:03d}",
        timestamp=datetime.now(),
        speaker="customer",
        text=segment.corrected_text
    )
    extraction = await agent.invoke(segment)
    results.append(Agent_output(**extraction))
print(results)
# Out:
# 2025-12-19 13:08:27,985 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# 2025-12-19 13:08:29,016 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "activities": [
#         "Plan and organize a trip to Egypt."
#     ],
#     "preferences": [
#         "Explore Egypt"
#     ],
#     "keywords": [
#         "travel Egypt"
#     ]
# }
# 2025-12-19 13:08:29,932 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "check_in": "2026-01-05",
#     "check_out": "2026-01-09",
#     "rooms": 1,
#     "city": "Cairo"
# }
# 2025-12-19 13:08:31,190 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "check_in": "",
#     "check_out": "",
#     "activities": [],
#     "preferences": [
#         "prefer staying in Cairo for a short duration",
#         "want to maximize time spent in Cairo"
#     ],
#     "keywords": [
#         "Cairo",
#         "five days",
#         "short stay",
#         "efficient use of time"
#     ]
# }
# 2025-12-19 13:08:32,881 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "city": "Cairo",
#     "activities": [
#         "Explore diverse nightlife venues in Cairo, such as cafes and clubs where locals discuss them.",
#         "Visit and experience nightlife spots like cafes and social clubs in Cairo."
#     ],
#     "preferences": [
#         "Nightlife experiences",
#         "Exploring local social scenes",
#         "Trying different venues"
#     ],
#     "keywords": [
#         "nightlife",
#         "cafes",
#         "social clubs",
#         "local experiences"
#     ]
# }
# 2025-12-19 13:08:34,261 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "activities": [
#         "Visit and explore the Great Pyramids of Giza.",
#         "Explore the Egyptian Museum in Cairo to learn about ancient artifacts and history.",
#         "Discover Khan el-Khalili, a historic bazaar known for its spices, textiles, and traditional crafts.",
#         "Enjoy a pleasant evening boat ride on the Nile with cultural performances and entertainment"
#     ],
#     "city": "Cairo"
# }
# 2025-12-19 13:08:36,331 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "activities": [
#         "Engage in morning sightseeing activities during the day",
#         "Experience nightlife events in the evening"
#     ],
#     "check_in": "2025-12-20",
#     "check_out": "2025-12-23",
#     "activities": [
#         "Plan a full day of sightseeing activities for two days"
#     ],
#     "preferences": [
#         "Prefer a mix of daytime exploration and nighttime entertainment"
#     ],
#     "keywords": [
#         "morning sightseeing",
#         "nightlife",
#         "strong itinerary",
#         " Nile cruise"
#     ]
# }
# 2025-12-19 13:08:37,770 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "activities": [
#         "Enjoy a peaceful and relaxing Nile River cruise or tour within a specified budget."
#     ],
#     "preferences": [
#         "Budget-friendly",
#         "Clean and well-organized accommodations",
#         "Moderate comfort level (not luxurious)"
#     ],
#     "keywords": [
#         "Nile cruise",
#         "relaxing trip",
#         "budget-friendly travel",
#         "moderate comfort"
#     ]
# }
# 2025-12-19 13:08:37,987 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {}
# 2025-12-19 13:08:38,807 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {
#     "check_in": "2026-01-15",
#     "check_out": "2026-02-04",
#     "preferences": ["flexible travel timing"]
# }
# 2025-12-19 13:08:39,025 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-19 13:08:39,225 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {}
# DEBUG - JSON Parse Error: Expecting value: line 1 column 1 (char 0)
# DEBUG - Extracted JSON: {}
# [Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=['Plan and organize a trip to Egypt.'], preferences=['Explore Egypt'], keywords=['travel Egypt']), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=1, city='Cairo', check_in='2026-01-05', check_out='2026-01-09', activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='', check_out='', activities=[], preferences=['prefer staying in Cairo for a short duration', 'want to maximize time spent in Cairo'], keywords=['Cairo', 'five days', 'short stay', 'efficient use of time']), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in=None, check_out=None, activities=['Explore diverse nightlife venues in Cairo, such as cafes and clubs where locals discuss them.', 'Visit and experience nightlife spots like cafes and social clubs in Cairo.'], preferences=['Nightlife experiences', 'Exploring local social scenes', 'Trying different venues'], keywords=['nightlife', 'cafes', 'social clubs', 'local experiences']), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in=None, check_out=None, activities=['Visit and explore the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo to learn about ancient artifacts and history.', 'Discover Khan el-Khalili, a historic bazaar known for its spices, textiles, and traditional crafts.', 'Enjoy a pleasant evening boat ride on the Nile with cultural performances and entertainment'], preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2025-12-20', check_out='2025-12-23', activities=['Plan a full day of sightseeing activities for two days'], preferences=['Prefer a mix of daytime exploration and nighttime entertainment'], keywords=['morning sightseeing', 'nightlife', 'strong itinerary', ' Nile cruise']), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=['Enjoy a peaceful and relaxing Nile River cruise or tour within a specified budget.'], preferences=['Budget-friendly', 'Clean and well-organized accommodations', 'Moderate comfort level (not luxurious)'], keywords=['Nile cruise', 'relaxing trip', 'budget-friendly travel', 'moderate comfort']), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2026-01-15', check_out='2026-02-04', activities=None, preferences=['flexible travel timing'], keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None)]

# %%
results
# Out:
# [Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=['Plan and organize a trip to Egypt.'], preferences=['Explore Egypt'], keywords=['travel Egypt']),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=1, city='Cairo', check_in='2026-01-05', check_out='2026-01-09', activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='', check_out='', activities=[], preferences=['prefer staying in Cairo for a short duration', 'want to maximize time spent in Cairo'], keywords=['Cairo', 'five days', 'short stay', 'efficient use of time']),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in=None, check_out=None, activities=['Explore diverse nightlife venues in Cairo, such as cafes and clubs where locals discuss them.', 'Visit and experience nightlife spots like cafes and social clubs in Cairo.'], preferences=['Nightlife experiences', 'Exploring local social scenes', 'Trying different venues'], keywords=['nightlife', 'cafes', 'social clubs', 'local experiences']),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in=None, check_out=None, activities=['Visit and explore the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo to learn about ancient artifacts and history.', 'Discover Khan el-Khalili, a historic bazaar known for its spices, textiles, and traditional crafts.', 'Enjoy a pleasant evening boat ride on the Nile with cultural performances and entertainment'], preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2025-12-20', check_out='2025-12-23', activities=['Plan a full day of sightseeing activities for two days'], preferences=['Prefer a mix of daytime exploration and nighttime entertainment'], keywords=['morning sightseeing', 'nightlife', 'strong itinerary', ' Nile cruise']),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=['Enjoy a peaceful and relaxing Nile River cruise or tour within a specified budget.'], preferences=['Budget-friendly', 'Clean and well-organized accommodations', 'Moderate comfort level (not luxurious)'], keywords=['Nile cruise', 'relaxing trip', 'budget-friendly travel', 'moderate comfort']),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2026-01-15', check_out='2026-02-04', activities=None, preferences=['flexible travel timing'], keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None)]
