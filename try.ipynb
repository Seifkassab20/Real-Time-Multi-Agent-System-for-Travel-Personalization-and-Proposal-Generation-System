# %%
import sys
sys.path.append("/Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/backend")

# %% [markdown]
# ## Testing STT

# %%
from backend.core.ASR.src.pipeline import TranscriptionService
default_path = "/Users/maryamsaad/Documents/ASR/trial.wav"
    

service = TranscriptionService()
result = await service.process_audio(default_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/myenv/lib/python3.13/site-packages/langsmith/run_helpers.py:487: UserWarning: Unrecognized run_type: db_operation. Must be one of: {'prompt', 'retriever', 'embedding', 'tool', 'llm', 'parser', 'chain'}. Did you mean @traceable(name='db_operation')?
#   warnings.warn(
# 2025-12-20 23:23:52,510 - ASR_Pipeline - INFO - Initializing TranscriptionService...
# 2025-12-20 23:23:52,524 - ASR_Pipeline - INFO - TranscriptionService initialization metadata: {'component': 'transcription_service_init', 'project': 'multi-agent-travel-recommendation-engine', 'environment_variables': {'DEVICE': 'mps', 'MODEL_NAME': 'facebook/seamless-m4t-v2-large', 'CORRECTION_MODEL': 'ministral-3:3b', 'OLLAMA_HOST': 'http://localhost:11434', 'CHUNK_LENGTH': '20.0', 'OVERLAP': '2.0'}, 'correction_engine_initialized': True, 'service_status': 'initialized_successfully'}
# 2025-12-20 23:23:52,524 - ASR_Pipeline - INFO - TranscriptionService initialized successfully.
# 2025-12-20 23:23:52,525 - ASR_Pipeline - INFO - Audio file: /Users/maryamsaad/Documents/ASR/trial.wav, Size: 17.72 MB
# http://localhost:11434
# 081d13b5aa9740e5843d56becc4fe9ec.IHzggxpzGRiccRyQrcdUgruy
# ministral-3:3b
# [audio] Loading: /Users/maryamsaad/Documents/ASR/trial.wav
# 2025-12-20 23:23:52,795 - ASR_Pipeline - INFO - Processing audio file: /Users/maryamsaad/Documents/ASR/trial.wav
# 2025-12-20 23:23:52,796 - ASR_Pipeline - INFO - Pipeline tracing metadata: {'component': 'asr_pipeline', 'project': 'multi-agent-travel-recommendation-engine', 'audio_file': '/Users/maryamsaad/Documents/ASR/trial.wav', 'file_size_mb': 17.72, 'target_language': 'arb'}
# [audio] Loaded: torch.Size([1, 9290688]), sr=48000Hz
# [audio] Resampling 48000Hz → 16000Hz...
# [audio] Duration: 193.56s (max: 20.0s)
# [audio] Normalizing amplitude...
# [audio] ✓ Preprocessed: shape=torch.Size([3096896]), range=[-1.000, 0.828]
#
# [inference] Starting CHUNKED transcription (lang=arb)...
# [audio] Loading: /Users/maryamsaad/Documents/ASR/trial.wav
# [audio] Loaded: torch.Size([1, 9290688]), sr=48000Hz
# [audio] Resampling 48000Hz → 16000Hz...
# [audio] Duration: 193.56s (max: 20.0s)
# [audio] Normalizing amplitude...
# [audio] ✓ Preprocessed: shape=torch.Size([3096896]), range=[-1.000, 0.828]
# [audio] Chunking audio into 20-second segments...
# [audio] Total chunks: 11
# [chunk 1/11] Processing...
# 2025-12-20 23:23:53,721 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('422 Client Error: unknown for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unprocessable entity: invalid Content-Length or length parameter for patch.019b3da5-c589-76e1-8978-5c07529fb282.outputs: field size 43803449 exceeds maximum allowed size of 26214400 bytes"}\n')
# /Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/backend/core/ASR/src/asr_infrence.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   token_ids = torch.tensor(token_ids, dtype=torch.long).unsqueeze(0)
# [chunk 1] Text: مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر
# [chunk 1] Avg confidence: 0.741
# [cleanup] MPS cache cleared for chunk 1
# [chunk 2/11] Processing...
# [chunk 2] Text: ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي
# [chunk 2] Avg confidence: 0.737
# [cleanup] MPS cache cleared for chunk 2
# [chunk 3/11] Processing...
# [chunk 3] Text: يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة
# [chunk 3] Avg confidence: 0.772
# [cleanup] MPS cache cleared for chunk 3
# [chunk 4/11] Processing...
# [chunk 4] Text: كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية
# [chunk 4] Avg confidence: 0.752
# [cleanup] MPS cache cleared for chunk 4
# [chunk 5/11] Processing...
# [chunk 5] Text: وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل
# [chunk 5] Avg confidence: 0.745
# [cleanup] MPS cache cleared for chunk 5
# [chunk 6/11] Processing...
# [chunk 6] Text: تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة
# [chunk 6] Avg confidence: 0.719
# [cleanup] MPS cache cleared for chunk 6
# [chunk 7/11] Processing...
# [chunk 7] Text: جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي
# [chunk 7] Avg confidence: 0.715
# [cleanup] MPS cache cleared for chunk 7
# [chunk 8/11] Processing...
# [chunk 8] Text: لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته
# [chunk 8] Avg confidence: 0.690
# [cleanup] MPS cache cleared for chunk 8
# [chunk 9/11] Processing...
# [chunk 9] Text: تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز
# [chunk 9] Avg confidence: 0.737
# [cleanup] MPS cache cleared for chunk 9
# [chunk 10/11] Processing...
# [chunk 10] Text: هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون
# [chunk 10] Avg confidence: 0.680
# [cleanup] MPS cache cleared for chunk 10
# [chunk 11/11] Processing...
# [chunk 11] Text: أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة
# [chunk 11] Avg confidence: 0.738
# [cleanup] MPS cache cleared for chunk 11
# 2025-12-20 23:24:17,795 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر' corrected_text='مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر. اه الحقيقة انا بفكر ازور مصر!' confidence=0.7409221651879224 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:20,590 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي' corrected_text='ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا و سهلا يا أستاذ جون. شرفتنا؟ قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي. انا ناوي اقعد حوالي خمسة ليالي.' confidence=0.7367354713637253 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:23,246 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة' corrected_text='يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة' confidence=0.7717744274572893 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:26,325 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية' corrected_text='كنت تفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنواة لايف شوية. نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها. برضه، عايزة ازور أماكن سياحية!' confidence=0.7518013874689738 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:28,898 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل' corrected_text='وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان القاهرة فعلا غنية بالحاجات دي. ممكن نزور الأهرامات، المتحف المصري، خان الخليلي، وكمان نرتبلك خروجات ليلية حلوة على النيل!' confidence=0.7454255505612022 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:32,092 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة' corrected_text='تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل، اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس ناخليه رايح مثلا جولة نيلية أو حاجة هائلة!' confidence=0.7186777591705322 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:34,748 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي' corrected_text='جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة، حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم. لو سمحتم لي' confidence=0.714698489119367 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:37,637 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته' corrected_text='لو تشرف لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقمي هو 1202550198 ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته.' confidence=0.6904925065381187 start_time=None end_time=None needs_review=True
# 2025-12-20 23:24:40,400 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز' corrected_text='تمام سجلتِك آخر حاجة، حضرتك جَاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم ١٥ ممتاز، هجهز!' confidence=0.7365610212087631 start_time=None end_time=None needs_review=False
# 2025-12-20 23:24:43,212 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# SEGMENT  raw_text='هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون' corrected_text='هذا الفيديو ممتاز، هجهز لك برنامج كامل مع ٣ خيارات للفنادق ونبعثهم على واتساب والايمايل. تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح. العفو يا أستاذ جون!' confidence=0.680328263176812 start_time=None end_time=None needs_review=True
# 2025-12-20 23:24:45,409 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-20 23:24:45,413 - ASR_Pipeline - INFO - Audio processing completed successfully.
# SEGMENT  raw_text='أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة' corrected_text='استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!' confidence=0.7378794727502046 start_time=None end_time=None needs_review=False
# Original URL: postgresql://neondb_owner:npg_uaY5PRTiD9zs@ep-rough-shadow-admgw9y6-pooler.c-2.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require
# Converted URL: postgresql+asyncpg://neondb_owner:npg_uaY5PRTiD9zs@ep-rough-shadow-admgw9y6-pooler.c-2.us-east-1.aws.neon.tech/neondb
# 2025-12-20 23:24:46,123 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('422 Client Error: unknown for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unprocessable entity: error parsing run for post.019b3da6-92e6-7f61-94a7-a3fac20ec23e: schema validation failed: run_type: run_type must be one of the following: \\"tool\\", \\"chain\\", \\"llm\\", \\"retriever\\", \\"embedding\\", \\"prompt\\", \\"parser\\""}\n')
# 2025-12-20 23:24:46,523 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-12-20 23:24:46,523 - sqlalchemy.engine.Engine - INFO - select pg_catalog.version()
# 2025-12-20 23:24:46,525 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-20 23:24:46,525 - sqlalchemy.engine.Engine - INFO - [raw sql] ()
# 2025-12-20 23:24:46,983 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-12-20 23:24:46,983 - sqlalchemy.engine.Engine - INFO - select current_schema()
# 2025-12-20 23:24:46,985 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-20 23:24:46,985 - sqlalchemy.engine.Engine - INFO - [raw sql] ()
# 2025-12-20 23:24:49,113 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-12-20 23:24:49,113 - sqlalchemy.engine.Engine - INFO - show standard_conforming_strings
# 2025-12-20 23:24:49,115 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-20 23:24:49,115 - sqlalchemy.engine.Engine - INFO - [raw sql] ()
# 2025-12-20 23:24:49,536 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-20 23:24:49,536 - sqlalchemy.engine.Engine - INFO - BEGIN (implicit)
# 2025-12-20 23:24:49,542 INFO sqlalchemy.engine.Engine INSERT INTO calls (call_id, call_context, started_at, ended_at) VALUES ($1::UUID, $2::JSONB, $3::TIMESTAMP WITHOUT TIME ZONE, $4::TIMESTAMP WITHOUT TIME ZONE)
# 2025-12-20 23:24:49,542 - sqlalchemy.engine.Engine - INFO - INSERT INTO calls (call_id, call_context, started_at, ended_at) VALUES ($1::UUID, $2::JSONB, $3::TIMESTAMP WITHOUT TIME ZONE, $4::TIMESTAMP WITHOUT TIME ZONE)
# 2025-12-20 23:24:49,544 INFO sqlalchemy.engine.Engine [generated in 0.00182s] (UUID('de1ef80f-2e99-4ea2-a090-334e648f51a9'), '[{"raw_text": "\\u0645\\u0633\\u0627\\u0621 \\u0627\\u0644\\u062e\\u064a\\u0631 \\u0634\\u0631\\u0643\\u0629 \\u062c\\u0648\\u0644\\u062f\\u0646 \\u0 ... (19971 characters truncated) ...  \\u0627\\u0644\\u0633\\u0644\\u0627\\u0645\\u0629!", "confidence": 0.7378794727502046, "start_time": null, "end_time": null, "needs_review": false}]', datetime.datetime(2025, 12, 20, 21, 23, 52, 525813), datetime.datetime(2025, 12, 20, 21, 24, 45, 414274))
# 2025-12-20 23:24:49,544 - sqlalchemy.engine.Engine - INFO - [generated in 0.00182s] (UUID('de1ef80f-2e99-4ea2-a090-334e648f51a9'), '[{"raw_text": "\\u0645\\u0633\\u0627\\u0621 \\u0627\\u0644\\u062e\\u064a\\u0631 \\u0634\\u0631\\u0643\\u0629 \\u062c\\u0648\\u0644\\u062f\\u0646 \\u0 ... (19971 characters truncated) ...  \\u0627\\u0644\\u0633\\u0644\\u0627\\u0645\\u0629!", "confidence": 0.7378794727502046, "start_time": null, "end_time": null, "needs_review": false}]', datetime.datetime(2025, 12, 20, 21, 23, 52, 525813), datetime.datetime(2025, 12, 20, 21, 24, 45, 414274))
# 2025-12-20 23:24:51,825 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-20 23:24:51,825 - sqlalchemy.engine.Engine - INFO - COMMIT
# 2025-12-20 23:24:52,012 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-20 23:24:52,012 - sqlalchemy.engine.Engine - INFO - BEGIN (implicit)
# 2025-12-20 23:24:52,017 INFO sqlalchemy.engine.Engine SELECT calls.call_id, calls.call_context, calls.started_at, calls.ended_at
# FROM calls
# WHERE calls.call_id = $1::UUID
# 2025-12-20 23:24:52,017 - sqlalchemy.engine.Engine - INFO - SELECT calls.call_id, calls.call_context, calls.started_at, calls.ended_at
# FROM calls
# WHERE calls.call_id = $1::UUID
# 2025-12-20 23:24:52,019 INFO sqlalchemy.engine.Engine [generated in 0.00130s] (UUID('de1ef80f-2e99-4ea2-a090-334e648f51a9'),)
# 2025-12-20 23:24:52,019 - sqlalchemy.engine.Engine - INFO - [generated in 0.00130s] (UUID('de1ef80f-2e99-4ea2-a090-334e648f51a9'),)
# 2025-12-20 23:24:52,890 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-20 23:24:52,890 - sqlalchemy.engine.Engine - INFO - ROLLBACK
# 2025-12-20 23:24:53,027 - ASR_Pipeline - INFO - New call record added with ID: de1ef80f-2e99-4ea2-a090-334e648f51a9

# %% [markdown]
# ## Load from script

# %%
# import json
# # Open file with UTF-8 encoding to handle special characters
# with open('test/script4.json', encoding='utf-8') as f:
#     script = json.load(f)
# print(script)
# result = script
# Out:
# ['مساء الخير، أنا عايز أطلع أجازة بسيطة على القاهرة.', 'رحلة كده تغيير جو من غير زحمة ولا مصاريف زيادة.', 'أهلاً بيك. تحب أعرف الميزانية الأول؟', 'الميزانية حوالي 8000 جنيه، ومش ناوي أصرف أكتر من كده.', 'الرحلة دي استجمام أكتر من أي حاجة.', 'تمام. عدد الأشخاص؟', 'أنا شخص واحد بس، ومحتاج أوضة واحدة.', 'تحب تحدد مواعيد السفر؟', 'الدخول هيكون يوم 1 فبراير 2026،', 'والخروج يوم 8 فبراير 2026.', 'يعني أسبوع كامل.', 'تحب تعمل إيه في القاهرة؟', 'حابب أزور خان الخليلي،', 'وكمان أجرب الأكل المصري الشعبي من الأماكن المعروفة.', 'بحب الحاجات التراثية والأجواء القديمة.', 'تحب الفندق يكون إيه مستواه؟', 'يفضل يكون اقتصادي،', 'بس أهم حاجة يكون نضيف وقريب من المناطق الشعبية.']

# %%
result
# Out:
# [TranscriptionSegment(raw_text='مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر', corrected_text='مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر. اه الحقيقة انا بفكر ازور مصر!', confidence=0.7409221651879224, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي', corrected_text='ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا و سهلا يا أستاذ جون. شرفتنا؟ قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي. انا ناوي اقعد حوالي خمسة ليالي.', confidence=0.7367354713637253, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة', corrected_text='يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة', confidence=0.7717744274572893, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية', corrected_text='كنت تفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنواة لايف شوية. نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها. برضه، عايزة ازور أماكن سياحية!', confidence=0.7518013874689738, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل', corrected_text='وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان القاهرة فعلا غنية بالحاجات دي. ممكن نزور الأهرامات، المتحف المصري، خان الخليلي، وكمان نرتبلك خروجات ليلية حلوة على النيل!', confidence=0.7454255505612022, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة', corrected_text='تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل، اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس ناخليه رايح مثلا جولة نيلية أو حاجة هائلة!', confidence=0.7186777591705322, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي', corrected_text='جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة، حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم. لو سمحتم لي', confidence=0.714698489119367, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته', corrected_text='لو تشرف لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقمي هو 1202550198 ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته.', confidence=0.6904925065381187, start_time=None, end_time=None, needs_review=True),
#  TranscriptionSegment(raw_text='تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز', corrected_text='تمام سجلتِك آخر حاجة، حضرتك جَاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم ١٥ ممتاز، هجهز!', confidence=0.7365610212087631, start_time=None, end_time=None, needs_review=False),
#  TranscriptionSegment(raw_text='هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون', corrected_text='هذا الفيديو ممتاز، هجهز لك برنامج كامل مع ٣ خيارات للفنادق ونبعثهم على واتساب والايمايل. تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح. العفو يا أستاذ جون!', confidence=0.680328263176812, start_time=None, end_time=None, needs_review=True),
#  TranscriptionSegment(raw_text='أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة', corrected_text='استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!', confidence=0.7378794727502046, start_time=None, end_time=None, needs_review=False)]

# %%
for segment in result:
    print(segment.corrected_text)
# Out:
# مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر. اه الحقيقة انا بفكر ازور مصر!
# ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا و سهلا يا أستاذ جون. شرفتنا؟ قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي. انا ناوي اقعد حوالي خمسة ليالي.
# يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة
# كنت تفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنواة لايف شوية. نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها. برضه، عايزة ازور أماكن سياحية!
# وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان القاهرة فعلا غنية بالحاجات دي. ممكن نزور الأهرامات، المتحف المصري، خان الخليلي، وكمان نرتبلك خروجات ليلية حلوة على النيل!
# تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل، اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس ناخليه رايح مثلا جولة نيلية أو حاجة هائلة!
# جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة، حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم. لو سمحتم لي
# لو تشرف لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقمي هو 1202550198 ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته.
# تمام سجلتِك آخر حاجة، حضرتك جَاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم ١٥ ممتاز، هجهز!
# هذا الفيديو ممتاز، هجهز لك برنامج كامل مع ٣ خيارات للفنادق ونبعثهم على واتساب والايمايل. تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح. العفو يا أستاذ جون!
# استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!

# %% [markdown]
# ## Testing Extraction Agent

# %%
from backend.core.extraction_agent.extraction_agent import ExtractionAgent
from backend.core.extraction_agent.models import TranscriptSegment, Agent_output
from datetime import datetime
import time

from collections import defaultdict

agent = ExtractionAgent()
results = []
aggregated_entities = defaultdict(list)
total_start = time.time()


# Process each sentence as a segment
for i, segment in enumerate(result):
    segment = TranscriptSegment(
        segment_id=f"seg_{i:03d}",
        timestamp=datetime.now(),
        speaker="customer",
        text=segment.corrected_text
    )
    extraction = await agent.invoke(segment)
    results.append(Agent_output(**extraction))
print(results)
# Out:
# 2025-12-20 23:27:44,009 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {}
# 2025-12-20 23:27:48,219 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# 2025-12-20 23:27:51,734 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"city":"Cairo","check_in":"2025-12-20","check_out":"2025-12-25"}
# 2025-12-20 23:27:55,847 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# 2025-12-20 23:27:58,897 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"city":"Cairo","activities":["Visit the Great Pyramids of Giza.","Visit the Egyptian Museum in Cairo.","Explore Khan el-Khalili bazaar in Cairo.","Enjoy pleasant night outings on the Nile River."]}
# 2025-12-20 23:28:03,575 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# 2025-12-20 23:28:08,290 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# 2025-12-20 23:28:10,600 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {}
# 2025-12-20 23:28:14,029 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"check_in":"2026-01-15"}
# 2025-12-20 23:28:17,723 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {}
# 2025-12-20 23:28:20,681 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"check_in":"2025-12-20"}
# [Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in='2025-12-20', check_out='2025-12-25', activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in=None, check_out=None, activities=['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.'], preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2026-01-15', check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None), Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2025-12-20', check_out=None, activities=None, preferences=None, keywords=None)]

# %%
results
# Out:
# [Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in='2025-12-20', check_out='2025-12-25', activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city='Cairo', check_in=None, check_out=None, activities=['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.'], preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2026-01-15', check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in=None, check_out=None, activities=None, preferences=None, keywords=None),
#  Agent_output(budget=None, adults=None, children=None, children_age=None, rooms=None, city=None, check_in='2025-12-20', check_out=None, activities=None, preferences=None, keywords=None)]

# %% [markdown]
# ## Testing recommendation engine

# %%
from backend.core.recommendation_engine.recommendation_orchestrator import build_user_profile_from_extraction , merge_value, MERGE_RULES , recommend

final_profile = {}
recommendations = []

# Process each segment extraction individually (real-time)
for i, segment in enumerate(results):
    print(f"\n{'='*60}")
    print(f"Processing Segment {i+1}/{len(results)}")
    print(f"{'='*60}")
    
    # Update profile with this segment's information
    for field, rule in MERGE_RULES.items():
        final_profile[field] = merge_value(
            final_profile.get(field),
            getattr(segment, field),
            rule
        )
    
    # Build user profile with accumulated information
    user_profile = build_user_profile_from_extraction(final_profile)
    print(f"\nUpdated User Profile:\n{user_profile}")
    
    # Get recommendation based on current accumulated profile
    recommendation_result = recommend(user_profile)
    recommendations.append(recommendation_result)
    print(f"\nRecommendation (with info up to segment {i+1}):")
    print(recommendation_result)

print(f"\n{'='*60}")
print("All segments processed!")
print(f"{'='*60}")
# Out:
# ============================================================
# Processing Segment 1/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 1):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}}
#
# ============================================================
# Processing Segment 2/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 2):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}}
#
# ============================================================
# Processing Segment 3/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 3):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': []}}
#
# ============================================================
# Processing Segment 4/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 4):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': []}}
#
# ============================================================
# Processing Segment 5/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 5):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}}
#
# ============================================================
# Processing Segment 6/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 6):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}}
#
# ============================================================
# Processing Segment 7/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 7):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}}
#
# ============================================================
# Processing Segment 8/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 8):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}}
#
# ============================================================
# Processing Segment 9/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 9):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}}
#
# ============================================================
# Processing Segment 10/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 10):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}}
#
# ============================================================
# Processing Segment 11/11
# ============================================================
#
# Updated User Profile:
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# Recommendation (with info up to segment 11):
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-20', 'end_date': '2025-12-25'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Visit the Egyptian Museum in Cairo.', 'Explore Khan el-Khalili bazaar in Cairo.', 'Enjoy pleasant night outings on the Nile River.']}}
#
# ============================================================
# All segments processed!
# ============================================================

# %%
recommendation_result
# Out:
# {'status': 'OK',
#  'budget_breakdown': {'hotel_total': 3600.0,
#   'activities_total': 2000.0,
#   'food_total': 1600.0,
#   'transport_total': 800.0,
#   'hotel_per_night': 514.2857142857143,
#   'activities_per_day': 285.7142857142857,
#   'food_per_day': 228.57142857142858},
#  'hotel': {'name': 'GOLDEN PYRAMiDS HUT HOTEL',
#   'city': 'Cairo',
#   'price_per_night': 4157.0,
#   'rating': 10.0,
#   'link': 'https://www.booking.com/hotel/eg/magic-hostel-pyramid.html?aid=304142&label=gen173nr-10CAQoggJCDHNlYXJjaF9jYWlyb0gzWARoQ4gBAZgBM7gBF8gBDNgBA-gBAfgBAYgCAagCAbgCzvWRygbAAgHSAiRhZGFmNWYzNi1kODA5LTQwMjUtYWQ0ZS03NzllOGM4NWNlMzLYAgHgAgE&ucfs=1&arphpl=1&checkin=2025-12-20&checkout=2025-12-23&group_adults=2&req_adults=2&no_rooms=2&group_children=2&req_children=2&age=3&req_age=3&age=7&req_age=7&hpos=4&hapos=4&sr_order=popularity&nflt=ht_id%3D204&srpvid=91359b67fb210087&srepoch=1766095585&all_sr_blocks=1459594005_417268856_3_42_0%2C1459594001_417268856_1_42_0&highlighted_blocks=1459594005_417268856_3_42_0%2C1459594001_417268856_1_42_0&matching_block_id=1459594005_417268856_3_42_0&sr_pri_blocks=1459594005_417268856_3_42_0__4961%2C1459594001_417268856_1_42_0__3773&from=searchresults',
#   'reason': 'High rating and fits within your hotel budget'},
#  'itinerary': {'Day 1': [{'type': 'activity',
#     'name': 'V TERRACE MALL',
#     'category': 'mall',
#     'city': 'Cairo',
#     'rating': 4.9,
#     'estimated_cost': 0,
#     'reason': 'Highly rated mall in Cairo'},
#    {'type': 'meal', 'name': 'Lunch', 'estimated_cost': 137.14},
#    {'type': 'activity',
#     'name': '5A shopping mall',
#     'category': 'mall',
#     'city': 'Cairo',
#     'rating': 4.7,
#     'estimated_cost': 0,
#     'reason': 'Highly rated mall in Cairo'},
#    {'type': 'activity',
#     'name': 'Mall of Arabia',
#     'category': 'mall',
#     'city': 'Giza',
#     'rating': 4.6,
#     'estimated_cost': 0,
#     'reason': 'Highly rated mall in Giza'},
#    {'type': 'meal', 'name': 'Dinner', 'estimated_cost': 91.43}],
#   'Day 2': [{'type': 'activity',
#     'name': 'The National Museum of Egyptian Civilization',
#     'category': 'museum',
#     'city': 'Cairo',
#     'rating': 4.7,
#     'estimated_cost': 350,
#     'reason': 'Highly rated museum in Cairo'},
#    {'type': 'meal', 'name': 'Lunch', 'estimated_cost': 137.14},
#    {'type': 'activity',
#     'name': 'Madinaty Central Park',
#     'category': 'park',
#     'city': 'Cairo',
#     'rating': 4.6,
#     'estimated_cost': 100,
#     'reason': 'Highly rated park in Cairo'},
#    {'type': 'activity',
#     'name': 'The Park at MoA',
#     'category': 'park',
#     'city': 'Giza',
#     'rating': 4.6,
#     'estimated_cost': 100,
#     'reason': 'Highly rated park in Giza'},
#    {'type': 'meal', 'name': 'Dinner', 'estimated_cost': 91.43}],
#   'Day 3': [{'type': 'activity',
#     'name': 'COVA Coffee Store',
#     'category': 'cafe',
#     'city': 'Cairo',
#     'rating': 4.6,
#     'estimated_cost': 250,
#     'reason': 'Highly rated cafe in Cairo'},
#    {'type': 'meal', 'name': 'Lunch', 'estimated_cost': 137.14},
#    {'type': 'activity',
#     'name': 'Stage El Nile',
#     'category': 'cafe',
#     'city': 'Giza',
#     'rating': 4.6,
#     'estimated_cost': 250,
#     'reason': 'Highly rated cafe in Giza'},
#    {'type': 'activity',
#     'name': 'Mohamed Mahmoud Khalil Museum',
#     'category': 'museum',
#     'city': 'Giza',
#     'rating': 4.6,
#     'estimated_cost': 350,
#     'reason': 'Highly rated museum in Giza'},
#    {'type': 'meal', 'name': 'Dinner', 'estimated_cost': 91.43}],
#   'Day 4': [{'type': 'meal', 'name': 'Lunch', 'estimated_cost': 137.14},
#    {'type': 'meal', 'name': 'Dinner', 'estimated_cost': 91.43}],
#   'Day 5': [{'type': 'meal', 'name': 'Lunch', 'estimated_cost': 137.14},
#    {'type': 'meal', 'name': 'Dinner', 'estimated_cost': 91.43}],
#   'Day 6': [{'type': 'meal', 'name': 'Lunch', 'estimated_cost': 137.14},
#    {'type': 'meal', 'name': 'Dinner', 'estimated_cost': 91.43}],
#   'Day 7': [{'type': 'meal', 'name': 'Lunch', 'estimated_cost': 137.14},
#    {'type': 'meal', 'name': 'Dinner', 'estimated_cost': 91.43}]}}

# %%
## Testing Profile Agent

# %%
from backend.core.profile_agent.profile_agent import ProfileAgent

profile_agent = ProfileAgent()

questions = await profile_agent.invoke(call_id="040f35e4-61f1-414e-8889-06fa132d06ba")

print(questions)
# Out:
# 2025-12-21 00:43:42,932 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-21 00:43:42,932 - sqlalchemy.engine.Engine - INFO - BEGIN (implicit)
# 2025-12-21 00:43:42,934 INFO sqlalchemy.engine.Engine SELECT customer_profiles.profile_id, customer_profiles.call_id, customer_profiles.start_date, customer_profiles.end_date, customer_profiles.budget_amount, customer_profiles.budget_currency, customer_profiles.adults, customer_profiles.children, customer_profiles.children_ages, customer_profiles.cities, customer_profiles.specific_sites, customer_profiles.interests, customer_profiles.accommodation_preference, customer_profiles.tour_style, customer_profiles.created_at, customer_profiles.last_updated
# FROM customer_profiles
# WHERE customer_profiles.call_id = $1::UUID
# 2025-12-21 00:43:42,934 - sqlalchemy.engine.Engine - INFO - SELECT customer_profiles.profile_id, customer_profiles.call_id, customer_profiles.start_date, customer_profiles.end_date, customer_profiles.budget_amount, customer_profiles.budget_currency, customer_profiles.adults, customer_profiles.children, customer_profiles.children_ages, customer_profiles.cities, customer_profiles.specific_sites, customer_profiles.interests, customer_profiles.accommodation_preference, customer_profiles.tour_style, customer_profiles.created_at, customer_profiles.last_updated
# FROM customer_profiles
# WHERE customer_profiles.call_id = $1::UUID
# 2025-12-21 00:43:42,935 INFO sqlalchemy.engine.Engine [generated in 0.00060s] (UUID('040f35e4-61f1-414e-8889-06fa132d06ba'),)
# 2025-12-21 00:43:42,935 - sqlalchemy.engine.Engine - INFO - [generated in 0.00060s] (UUID('040f35e4-61f1-414e-8889-06fa132d06ba'),)
# 2025-12-21 00:43:43,401 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-21 00:43:43,401 - sqlalchemy.engine.Engine - INFO - ROLLBACK
# DEBUG - Profile data: {}
# 2025-12-21 00:43:52,696 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: questions=[question_response(question='When would you like to start your trip, and how many days are you planning to travel?', fields_filling=['start_date', 'end_date']), question_response(question='How many adults and children will be traveling with you, and could you let me know the ages of the children?', fields_filling=['adults', 'children', 'ages']), question_response(question='What budget range are you considering for this trip, and which currency would you prefer to use?', fields_filling=['budget_amount', 'budget_currency']), question_response(question='Which cities or destinations are you interested in visiting?', fields_filling=['cities']), question_response(question='What type of experiences are you most interested in, and do you have any preferences for accommodation or tour style?', fields_filling=['interests', 'accommodation_preference', 'tour_style'])]
# {"questions":[{"question":"When would you like to start your trip, and how many days are you planning to travel?","fields_filling":["start_date","end_date"]},{"question":"How many adults and children will be traveling with you, and could you let me know the ages of the children?","fields_filling":["adults","children","ages"]},{"question":"What budget range are you considering for this trip, and which currency would you prefer to use?","fields_filling":["budget_amount","budget_currency"]},{"question":"Which cities or destinations are you interested in visiting?","fields_filling":["cities"]},{"question":"What type of experiences are you most interested in, and do you have any preferences for accommodation or tour style?","fields_filling":["interests","accommodation_preference","tour_style"]}]}

# %%
import json

data = json.loads(questions)

for i, question in enumerate(data["questions"]):
    print(f"Q.{i+1} ------------------------------\n")
    print(f"Question: {question["question"]}\n")
    print(f"Required Field To Fill: {question["fields_filling"]}\n")
# Out:
# Q.1 ------------------------------
#
# Question: When would you like to start your trip, and how many days are you planning to travel?
#
# Required Field To Fill: ['start_date', 'end_date']
#
# Q.2 ------------------------------
#
# Question: How many adults and children will be traveling with you?
#
# Required Field To Fill: ['adults', 'children']
#
# Q.3 ------------------------------
#
# Question: What budget range are you considering for this trip, and which currency would you prefer to work with?
#
# Required Field To Fill: ['budget_amount', 'budget_currency']
#
# Q.4 ------------------------------
#
# Question: Which cities or destinations are you interested in visiting?
#
# Required Field To Fill: ['cities']
#
# Q.5 ------------------------------
#
# Question: What type of experiences are you most interested in? For example: cultural sites, adventure activities, relaxation, food tours, or historical landmarks?
#
# Required Field To Fill: ['interests']

# %% [markdown]
# ## Entire workflow

# %%
import asyncio
import uuid
from datetime import datetime
from backend.core.ASR.src.pipeline import TranscriptionService
from backend.core.extraction_agent.extraction_agent import ExtractionAgent
from backend.core.extraction_agent.models import TranscriptSegment, Agent_output
from backend.core.profile_agent.profile_agent import ProfileAgent
from backend.core.recommendation_engine.recommendation_orchestrator import (
    build_user_profile_from_extraction,
    merge_value,
    MERGE_RULES,
    recommend
)

# ------------------------------------------------------------------
# Initialization
# ------------------------------------------------------------------

audio_path = "/Users/maryamsaad/Documents/ASR/trial.wav"

asr_service = TranscriptionService()
extraction_agent = ExtractionAgent()
profile_agent = ProfileAgent()
final_profile = {}
recommendations = []

# ------------------------------------------------------------------
# Helpers
# ------------------------------------------------------------------

def merge_extraction_into_profile(profile: dict, extraction: Agent_output):
    for field, rule in MERGE_RULES.items():
        profile[field] = merge_value(
            profile.get(field),
            getattr(extraction, field, None),
            rule
        )

# ------------------------------------------------------------------
# Main Orchestrator
# ------------------------------------------------------------------

async def main():
    segment_count = 0

    async for asr_segment, call_id in asr_service.stream_audio(audio_path):
        segment_count += 1

        print(f"\n{'='*60}")
        print(f"Processing Segment {segment_count}")
        print(f"{'='*60}")
        print(f"[ASR] {asr_segment.corrected_text}")

        # Build transcript segment
        transcript = TranscriptSegment(
            segment_id=str(uuid.uuid4()),
            timestamp=datetime.utcnow(),
            speaker="customer",
            text=asr_segment.corrected_text
        )

        # Extract entities
        extraction_result = await extraction_agent.invoke(transcript)
        extraction = Agent_output(**extraction_result)

        print(f"[EXTRACTION] {extraction}")

        # Merge into accumulated profile
        merge_extraction_into_profile(final_profile, extraction)

        # Build user profile
        user_profile = build_user_profile_from_extraction(final_profile)
        print(f"\n[USER PROFILE]")
        print(user_profile)

        # Recommend
        recommendation_result = recommend(user_profile)
        recommendations.append(recommendation_result)

        print(f"\n[RECOMMENDATION]")
        print(recommendation_result)

        #User profile completion
        # questions = await profile_agent.invoke(call_id=call_id)
        # print(f"\n[PROFILE AGENT QUESTIONS]")
        # print(questions)

    print(f"\n{'='*60}")
    print("All segments processed!")
    print(f"{'='*60}")

# ------------------------------------------------------------------
# Entry Point
# ------------------------------------------------------------------

if __name__ == "__main__":
    await main()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-12-21 01:01:15,651 - ASR_Pipeline - INFO - Initializing Real-Time TranscriptionService...
# 2025-12-21 01:01:15,661 - ASR_Pipeline - INFO - TranscriptionService initialization metadata: {'component': 'transcription_service_init', 'project': 'multi-agent-travel-recommendation-engine', 'environment_variables': {'DEVICE': 'mps', 'MODEL_NAME': 'facebook/seamless-m4t-v2-large', 'CORRECTION_MODEL': 'ministral-3:3b', 'OLLAMA_HOST': 'http://localhost:11434', 'CHUNK_LENGTH': '2.0', 'OVERLAP': '0.5', 'REAL_TIME_MODE': 'enabled'}, 'correction_engine_initialized': True, 'service_status': 'initialized_successfully', 'mode': 'real_time_streaming'}
# 2025-12-21 01:01:15,662 - ASR_Pipeline - INFO - TranscriptionService initialized successfully.
# 2025-12-21 01:01:15,666 - ASR_Pipeline - INFO - Streaming audio file: /Users/maryamsaad/Documents/ASR/trial.wav
# http://localhost:11434
# 081d13b5aa9740e5843d56becc4fe9ec.IHzggxpzGRiccRyQrcdUgruy
# ministral-3:3b
# Original URL: postgresql://neondb_owner:npg_uaY5PRTiD9zs@ep-rough-shadow-admgw9y6-pooler.c-2.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require
# Converted URL: postgresql+asyncpg://neondb_owner:npg_uaY5PRTiD9zs@ep-rough-shadow-admgw9y6-pooler.c-2.us-east-1.aws.neon.tech/neondb
# 2025-12-21 01:01:16,858 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-12-21 01:01:16,858 - sqlalchemy.engine.Engine - INFO - select pg_catalog.version()
# 2025-12-21 01:01:16,861 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-21 01:01:16,861 - sqlalchemy.engine.Engine - INFO - [raw sql] ()
# 2025-12-21 01:01:17,330 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-12-21 01:01:17,330 - sqlalchemy.engine.Engine - INFO - select current_schema()
# 2025-12-21 01:01:17,331 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-21 01:01:17,331 - sqlalchemy.engine.Engine - INFO - [raw sql] ()
# 2025-12-21 01:01:18,038 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-12-21 01:01:18,038 - sqlalchemy.engine.Engine - INFO - show standard_conforming_strings
# 2025-12-21 01:01:18,040 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-21 01:01:18,040 - sqlalchemy.engine.Engine - INFO - [raw sql] ()
# 2025-12-21 01:01:18,488 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-21 01:01:18,488 - sqlalchemy.engine.Engine - INFO - BEGIN (implicit)
# 2025-12-21 01:01:18,492 INFO sqlalchemy.engine.Engine INSERT INTO calls (call_id, call_context, started_at, ended_at) VALUES ($1::UUID, $2::JSONB, $3::TIMESTAMP WITHOUT TIME ZONE, $4::TIMESTAMP WITHOUT TIME ZONE)
# 2025-12-21 01:01:18,492 - sqlalchemy.engine.Engine - INFO - INSERT INTO calls (call_id, call_context, started_at, ended_at) VALUES ($1::UUID, $2::JSONB, $3::TIMESTAMP WITHOUT TIME ZONE, $4::TIMESTAMP WITHOUT TIME ZONE)
# 2025-12-21 01:01:18,493 INFO sqlalchemy.engine.Engine [generated in 0.00151s] (UUID('776fbf47-ea6e-4330-aed7-f271f328fa76'), '[]', datetime.datetime(2025, 12, 20, 23, 1, 15, 666959), None)
# 2025-12-21 01:01:18,493 - sqlalchemy.engine.Engine - INFO - [generated in 0.00151s] (UUID('776fbf47-ea6e-4330-aed7-f271f328fa76'), '[]', datetime.datetime(2025, 12, 20, 23, 1, 15, 666959), None)
# 2025-12-21 01:01:18,952 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-21 01:01:18,952 - sqlalchemy.engine.Engine - INFO - COMMIT
# 2025-12-21 01:01:19,103 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-21 01:01:19,103 - sqlalchemy.engine.Engine - INFO - BEGIN (implicit)
# 2025-12-21 01:01:19,108 INFO sqlalchemy.engine.Engine SELECT calls.call_id, calls.call_context, calls.started_at, calls.ended_at
# FROM calls
# WHERE calls.call_id = $1::UUID
# 2025-12-21 01:01:19,108 - sqlalchemy.engine.Engine - INFO - SELECT calls.call_id, calls.call_context, calls.started_at, calls.ended_at
# FROM calls
# WHERE calls.call_id = $1::UUID
# 2025-12-21 01:01:19,109 INFO sqlalchemy.engine.Engine [generated in 0.00120s] (UUID('776fbf47-ea6e-4330-aed7-f271f328fa76'),)
# 2025-12-21 01:01:19,109 - sqlalchemy.engine.Engine - INFO - [generated in 0.00120s] (UUID('776fbf47-ea6e-4330-aed7-f271f328fa76'),)
# 2025-12-21 01:01:19,545 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-21 01:01:19,545 - sqlalchemy.engine.Engine - INFO - ROLLBACK
# 2025-12-21 01:01:19,689 - ASR_Pipeline - INFO - New call record added with ID: 776fbf47-ea6e-4330-aed7-f271f328fa76
# [audio] Loading: /Users/maryamsaad/Documents/ASR/trial.wav
# [audio] Loaded: torch.Size([1, 9290688]), sr=48000Hz
# [audio] Resampling 48000Hz → 16000Hz...
# [audio] Duration: 193.56s (max: 20.0s)
# [audio] Normalizing amplitude...
# [audio] ✓ Preprocessed: shape=torch.Size([3096896]), range=[-1.000, 0.828]
# [chunk 1/11] Processing...
# 2025-12-21 01:01:20,520 - langsmith.client - WARNING - Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('422 Client Error: unknown for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unprocessable entity: invalid Content-Length or length parameter for patch.019b3dfe-fde1-73d0-ba0d-37cf8040c997.outputs: field size 43803449 exceeds maximum allowed size of 26214400 bytes"}\n')
# /Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/backend/core/ASR/src/asr_infrence.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   token_ids = torch.tensor(token_ids, dtype=torch.long).unsqueeze(0)
# [chunk 1] Text: مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر
# [chunk 1] Avg confidence: 0.741
# 2025-12-21 01:01:25,390 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# /var/folders/c2/f9lh6rmd4q1648_pfl1636zw0000gn/T/ipykernel_24891/3677996655.py:57: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp=datetime.utcnow(),
# ============================================================
# Processing Segment 1
# ============================================================
# [ASR] مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر. اه الحقيقة انا بفكر ازور مصر؟
# 2025-12-21 01:01:28,524 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {}
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in=None check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}}
# [chunk 2/11] Processing...
# [chunk 2] Text: ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي
# [chunk 2] Avg confidence: 0.737
# 2025-12-21 01:01:33,768 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-21 01:01:33,781 - llm - ERROR - LLM Error [response_parsing]: Invalid json output: ```json
# {
#   "corrected_text": "ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا و سهلا يا أستاذ جون! شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي، انا ناوي اقعد حوالي خمس ليالي.",
#   "original_text": """ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي""",
#   "requires_confirmation": false,
#   "changes_made": true
# }
# ```
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE
# 2025-12-21 01:01:33,782 - llm - WARNING - Parsing failed: Invalid json output: ```json
# {
#   "corrected_text": "ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا و سهلا يا أستاذ جون! شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي، انا ناوي اقعد حوالي خمس ليالي.",
#   "original_text": """ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي""",
#   "requires_confirmation": false,
#   "changes_made": true
# }
# ```
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE
# ============================================================
# Processing Segment 2
# ============================================================
# [ASR] ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي
# 2025-12-21 01:01:38,397 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in=None check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 7, 'start_date': None, 'end_date': None}, 'destination': None, 'interests': []}}
# [chunk 3/11] Processing...
# [chunk 3] Text: يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة
# [chunk 3] Avg confidence: 0.772
# 2025-12-21 01:01:43,115 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 3
# ============================================================
# [ASR] يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة
# 2025-12-21 01:01:47,330 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"city":"Cairo","check_in":"2025-12-21","check_out":"2025-12-26"}
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city='Cairo' check_in='2025-12-21' check_out='2025-12-26' activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': []}}
# [chunk 4/11] Processing...
# [chunk 4] Text: كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية
# [chunk 4] Avg confidence: 0.752
# 2025-12-21 01:01:53,086 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 4
# ============================================================
# [ASR] كنت تفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنواة لايف شوية. نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها. برضه، عايزة ازور أماكن سياحية.
# 2025-12-21 01:01:58,376 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in=None check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': []}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': []}}
# [chunk 5/11] Processing...
# [chunk 5] Text: وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل
# [chunk 5] Avg confidence: 0.745
# 2025-12-21 01:02:03,388 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 5
# ============================================================
# [ASR] وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان القاهرة فعلا غنية بالحاجات دي. ممكن نزور الأهرامات، المتحف المصري، خان الخليلي، وكمان نرتبلك خروجات ليلية حلوة على النيل!
# 2025-12-21 01:02:07,300 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"city":"Cairo","activities":["Visit the Great Pyramids of Giza.","Explore the Egyptian Museum in Cairo.","Shop and experience the historic Khan el-Khalili bazaar.","Enjoy a pleasant nighttime outing along the Nile River."]}
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city='Cairo' check_in=None check_out=None activities=['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.'] preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}}
# [chunk 6/11] Processing...
# [chunk 6] Text: تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة
# [chunk 6] Avg confidence: 0.719
# 2025-12-21 01:02:13,181 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 6
# ============================================================
# [ASR] تحبي يكون البرنامج موزع بين سياحة الصبح ونايت لايف بالليل، اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس ناخليه رايح مثلا جولة نيلية أو حاجة هائلة!
# 2025-12-21 01:02:18,465 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in=None check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}}
# [chunk 7/11] Processing...
# [chunk 7] Text: جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي
# [chunk 7] Avg confidence: 0.715
# 2025-12-21 01:02:23,123 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 7
# ============================================================
# [ASR] جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة. حابب نشتغل عليها يعني، متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم. لو تسمح لي!
# 2025-12-21 01:02:27,771 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response:
# DEBUG - No content extracted
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in=None check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}}
# [chunk 8/11] Processing...
# [chunk 8] Text: لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته
# [chunk 8] Avg confidence: 0.690
# 2025-12-21 01:02:32,682 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 8
# ============================================================
# [ASR] لو تشرح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقمي هو 1202550198. ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته.
# 2025-12-21 01:02:35,364 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {}
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in=None check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}}
# [chunk 9/11] Processing...
# [chunk 9] Text: تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز
# [chunk 9] Avg confidence: 0.737
# 2025-12-21 01:02:40,042 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 9
# ============================================================
# [ASR] تمام سجلتِك آخر حاجة، حضرتك جاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز، هجهز!
# 2025-12-21 01:02:44,049 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"check_in":"2026-01-15"}
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in='2026-01-15' check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}}
# [chunk 10/11] Processing...
# [chunk 10] Text: هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون
# [chunk 10] Avg confidence: 0.680
# 2025-12-21 01:02:48,975 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 10
# ============================================================
# [ASR] هذا الفيديو ممتاز، هجهز لك برنامج كامل مع ٣ خيارات للفنادق ونبعثهم على واتساب والايمايل، تمام يا مريم شكرا لك، يا مريم! حقيقي شرح كل حاجة بوضوح، العفو يا أستاذ جون!
# 2025-12-21 01:02:53,086 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {}
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in=None check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}}
# [chunk 11/11] Processing...
# [chunk 11] Text: أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة
# [chunk 11] Avg confidence: 0.738
# 2025-12-21 01:02:56,642 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ============================================================
# Processing Segment 11
# ============================================================
# [ASR] استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!
# 2025-12-21 01:02:59,153 - httpx - INFO - HTTP Request: POST https://ollama.com/api/chat "HTTP/1.1 200 OK"
# DEBUG - Response: {"check_in":"2025-12-21"}
# [EXTRACTION] budget=None adults=None children=None children_age=None rooms=None city=None check_in='2025-12-21' check_out=None activities=None preferences=None keywords=None
#
# [USER PROFILE]
# {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}
# Error creating plan: unsupported operand type(s) for *: 'NoneType' and 'float'
#
# [RECOMMENDATION]
# {'error': "unsupported operand type(s) for *: 'NoneType' and 'float'", 'profile': {'budget': {'total': None}, 'travelers': {'adults': None, 'children': None, 'children_age': None}, 'rooms': None, 'dates': {'days': 5, 'start_date': '2025-12-21', 'end_date': '2025-12-26'}, 'destination': 'Cairo', 'interests': ['Visit the Great Pyramids of Giza.', 'Explore the Egyptian Museum in Cairo.', 'Shop and experience the historic Khan el-Khalili bazaar.', 'Enjoy a pleasant nighttime outing along the Nile River.']}}
# 2025-12-21 01:02:59,161 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-21 01:02:59,161 - sqlalchemy.engine.Engine - INFO - BEGIN (implicit)
# 2025-12-21 01:02:59,163 INFO sqlalchemy.engine.Engine INSERT INTO calls (call_id, call_context, started_at, ended_at) VALUES ($1::UUID, $2::JSONB, $3::TIMESTAMP WITHOUT TIME ZONE, $4::TIMESTAMP WITHOUT TIME ZONE)
# 2025-12-21 01:02:59,163 - sqlalchemy.engine.Engine - INFO - INSERT INTO calls (call_id, call_context, started_at, ended_at) VALUES ($1::UUID, $2::JSONB, $3::TIMESTAMP WITHOUT TIME ZONE, $4::TIMESTAMP WITHOUT TIME ZONE)
# 2025-12-21 01:02:59,165 INFO sqlalchemy.engine.Engine [cached since 100.7s ago] (UUID('8de0c3ac-0eb5-41a4-84d5-d94a67ad985e'), '[{"raw_text": "\\u0645\\u0633\\u0627\\u0621 \\u0627\\u0644\\u062e\\u064a\\u0631 \\u0634\\u0631\\u0643\\u0629 \\u062c\\u0648\\u0644\\u062f\\u0646 \\u0 ... (19935 characters truncated) ...  \\u0627\\u0644\\u0633\\u0644\\u0627\\u0645\\u0629!", "confidence": 0.7378794727502046, "start_time": null, "end_time": null, "needs_review": false}]', datetime.datetime(2025, 12, 20, 23, 1, 15, 666959), datetime.datetime(2025, 12, 20, 23, 2, 59, 158304))
# 2025-12-21 01:02:59,165 - sqlalchemy.engine.Engine - INFO - [cached since 100.7s ago] (UUID('8de0c3ac-0eb5-41a4-84d5-d94a67ad985e'), '[{"raw_text": "\\u0645\\u0633\\u0627\\u0621 \\u0627\\u0644\\u062e\\u064a\\u0631 \\u0634\\u0631\\u0643\\u0629 \\u062c\\u0648\\u0644\\u062f\\u0646 \\u0 ... (19935 characters truncated) ...  \\u0627\\u0644\\u0633\\u0644\\u0627\\u0645\\u0629!", "confidence": 0.7378794727502046, "start_time": null, "end_time": null, "needs_review": false}]', datetime.datetime(2025, 12, 20, 23, 1, 15, 666959), datetime.datetime(2025, 12, 20, 23, 2, 59, 158304))
# 2025-12-21 01:02:59,624 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-21 01:02:59,624 - sqlalchemy.engine.Engine - INFO - COMMIT
# 2025-12-21 01:02:59,769 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-21 01:02:59,769 - sqlalchemy.engine.Engine - INFO - BEGIN (implicit)
# 2025-12-21 01:02:59,770 INFO sqlalchemy.engine.Engine SELECT calls.call_id, calls.call_context, calls.started_at, calls.ended_at
# FROM calls
# WHERE calls.call_id = $1::UUID
# 2025-12-21 01:02:59,770 - sqlalchemy.engine.Engine - INFO - SELECT calls.call_id, calls.call_context, calls.started_at, calls.ended_at
# FROM calls
# WHERE calls.call_id = $1::UUID
# 2025-12-21 01:02:59,770 INFO sqlalchemy.engine.Engine [cached since 100.7s ago] (UUID('8de0c3ac-0eb5-41a4-84d5-d94a67ad985e'),)
# 2025-12-21 01:02:59,770 - sqlalchemy.engine.Engine - INFO - [cached since 100.7s ago] (UUID('8de0c3ac-0eb5-41a4-84d5-d94a67ad985e'),)
# 2025-12-21 01:03:00,073 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-21 01:03:00,073 - sqlalchemy.engine.Engine - INFO - ROLLBACK
# 2025-12-21 01:03:00,217 - ASR_Pipeline - INFO - New call record added with ID: 8de0c3ac-0eb5-41a4-84d5-d94a67ad985e
# ============================================================
# All segments processed!
# ============================================================
