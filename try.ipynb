# %%
import sys
sys.path.append("/Users/maryamsaad/Documents/ASR")

# %%
from ASR.src.pipeline import TranscriptionService
default_path = "/Users/maryamsaad/Documents/ASR/trial.wav"
    

service = TranscriptionService()
result = service.process_audio(default_path)
print("\n--- Final Corrected Output ---")
print(result.full_corrected_text)
print("------------------------------")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# [Seamless] ✓ Model loaded successfully.
# http://localhost:11434
# f1f1b3b476804e1fa0dec1fd5614f6ad.3Kbx433VLB3s1Bq-BfSR93FD
# ministral-3:3b
# 2025-12-15 15:23:46,300 - ASR_Pipeline - INFO - Initializing TranscriptionService...
# 2025-12-15 15:23:46,305 - ASR_Pipeline - INFO - TranscriptionService initialized successfully.
# 2025-12-15 15:23:46,305 - ASR_Pipeline - INFO - Processing audio file: /Users/maryamsaad/Documents/ASR/trial.wav
# {'corrected_text': 'Hello, world!', 'original_text': 'Hello, world!', 'requires_confirmation': True, 'changes_made': False}
# http://localhost:11434
# f1f1b3b476804e1fa0dec1fd5614f6ad.3Kbx433VLB3s1Bq-BfSR93FD
# ministral-3:3b
#
# [inference] Starting CHUNKED transcription (lang=arb)...
# [audio] Loading: /Users/maryamsaad/Documents/ASR/trial.wav
# [audio] Loaded: torch.Size([1, 9290688]), sr=48000Hz
# [audio] Resampling 48000Hz → 16000Hz...
# [audio] Duration: 193.56s (max: 20.0s)
# [audio] Normalizing amplitude...
# [audio] ✓ Preprocessed: shape=torch.Size([3096896]), range=[-1.000, 0.828]
# [audio] Chunking audio into 20-second segments...
# [audio] Total chunks: 11
# [chunk 1/11] Processing...
# /Users/maryamsaad/Documents/Real-Time-Multi-Agent-System-for-Travel-Personalization-and-Proposal-Generation-System/ASR/new_src/asr_infrence.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   token_ids = torch.tensor(token_ids, dtype=torch.long).unsqueeze(0)
# [chunk 1] Text: مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر
# [chunk 1] Avg confidence: 0.741
# [chunk 2/11] Processing...
# [chunk 2] Text: ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي
# [chunk 2] Avg confidence: 0.737
# [chunk 3/11] Processing...
# [chunk 3] Text: يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة
# [chunk 3] Avg confidence: 0.772
# [chunk 4/11] Processing...
# [chunk 4] Text: كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية
# [chunk 4] Avg confidence: 0.752
# [chunk 5/11] Processing...
# [chunk 5] Text: وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل
# [chunk 5] Avg confidence: 0.745
# [chunk 6/11] Processing...
# [chunk 6] Text: تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة
# [chunk 6] Avg confidence: 0.719
# [chunk 7/11] Processing...
# [chunk 7] Text: جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي
# [chunk 7] Avg confidence: 0.715
# [chunk 8/11] Processing...
# [chunk 8] Text: لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته
# [chunk 8] Avg confidence: 0.690
# [chunk 9/11] Processing...
# [chunk 9] Text: تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز
# [chunk 9] Avg confidence: 0.737
# [chunk 10/11] Processing...
# [chunk 10] Text: هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون
# [chunk 10] Avg confidence: 0.680
# [chunk 11/11] Processing...
# [chunk 11] Text: أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة
# [chunk 11] Avg confidence: 0.738
# 2025-12-15 15:24:08,371 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:11,007 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:13,537 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:16,471 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:18,925 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:21,917 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:24,453 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:27,213 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:29,846 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:32,561 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:34,699 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:34,701 - ASR_Pipeline - INFO - Audio processing completed successfully.
# --- Final Corrected Output ---
# مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر. اه الحقيقة انا بفكر ازور مصر! ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا وسهلا يا أستاذ جون! شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي، انا ناوي اقعد حوالي خمس ليالي. يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة كنت بتفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنواة لايف شوية. نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها. برضه عايزة ازور أماكن سياحية. وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان القاهرة فعلا غنية بالحاجات دي. ممكن نزور الأهرامات والمتحف المصري وخان الخليلي. كمان نرتبلك خروجات ليلية حلوة على النيل! تحبي يكون البرنامج موزع بين سياحة الصبح ونايت لايف بالليل، اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس ناخليه رايح مثلا جولة نيلية أو حاجة هائلة! جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة. حابب نشتغل عليها، يعني متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم. لو تسمح لي لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقمي هو 1202550198 ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته. تمام سجلتِك آخر حاجة، حضرتك جاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم ١٥ ممتاز، هجهز! هذا الفيديو ممتاز، هجهز لك برنامج كامل مع ٣ خيارات للفنادق ونبعثهم على واتساب والايمايل. تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح. العفو يا أستاذ جون! استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!
# ------------------------------

# %%
corrected=result.full_raw_text
corrected
# Out:
# 'مساء الخير شركة جولدن ترال مع حضرتك مريم من قسم المبيعات ازاي اقدر اساعدك مساء النور يا مريم انا اسمي جون كارتر اه الحقيقة انا بفكر ازور مصر ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل اهلا و سهلا يا أستاذ جون شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد لا لوحدي انا ناوي اقعد حوالي 5 ليالي يعني مش فترة طويلة بس عايز استغل الوقت على قد ما اقدر تمام خمس ليالي مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية كمان بصراحة كنت بفكر في القاهرة كنت بفكر في القاهرة لان فيها كل حاجة تقريبا وكمان يعني انا مهتم بالنايت لايف شوية نفسي اجرب اماكن مختلفة بالليل زي الكافيهات او النوادي اللي الناس بتتكلم عنها وبرضه عايزة ازور اماكن سياحية وبرضه عايزة ازور اماكن سياحية مشهورة ممتاز القاهرة فعلا غنية بالحاجات دي ممكن نزور الأهرامات المتحف المصري خان الخليلي وكمان نرتبلك خروجات ليلية حلوة على النيل تحبي يكون البرنامج موزع بين سياحة الصبح و نايت لايف بالليل اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف واليوم الخامس نخليه رايح مثلا جولة نيلية او حاجة هائلة جولة نيلية او حاجة هادئة تمام جدا في ميزانية معينة حابب نشتغل عليها يعني متوسط مش عايز حاجة فخمة اوي بس نظيفة ومرتبة مفهوم ولو تسمح لي لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح اكيد رقمي هو زائد 1 2 0 2 5 5 0 1 9 8 ممكن تتصلي في اي وقت بعد الظهر تمام سجلته تمام سجلته اخر حاجة حضرتك جاي في اي وقت تقريبا غالبا في نص الشهر الجاي لسه ما حددتش اليوم بالظبط بس هيكون حوالي يوم 15 ممتاز هجهز هذا الفيديو ممتاز هجهز لك برنامج كامل مع 3 خيارات للفنادق ونبعثهم على واتساب والايمايل تمام يا مريم شكرا لك جدا حقيقي شرح كل حاجة بوضوح العفو يا أستاذ جون أستاذ جون، ده واجبنا نتشرف بزيارتك لمصر يومك جميل وأنتي كمان مع السلامة'

# %%
import re

def add_newlines(text):
    # Add newline after . or ? if not already followed by one
    text = re.sub(r'([.?])\s*', r'\1\n', text)
    return text.strip()
corrected = result.full_corrected_text   # or whatever your field is
formatted = add_newlines(corrected)
print(formatted.replace(".",""))
# Out:
# مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر
# اه الحقيقة انا بفكر ازور مصر! ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا وسهلا يا أستاذ جون! شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي، انا ناوي اقعد حوالي خمس ليالي
# يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة كنت بتفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنواة لايف شوية
# نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها
# برضه عايزة ازور أماكن سياحية
# وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان القاهرة فعلا غنية بالحاجات دي
# ممكن نزور الأهرامات والمتحف المصري وخان الخليلي
# كمان نرتبلك خروجات ليلية حلوة على النيل! تحبي يكون البرنامج موزع بين سياحة الصبح ونايت لايف بالليل، اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس ناخليه رايح مثلا جولة نيلية أو حاجة هائلة! جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة
# حابب نشتغل عليها، يعني متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم
# لو تسمح لي لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقمي هو 1202550198 ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته
# تمام سجلتِك آخر حاجة، حضرتك جاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم ١٥ ممتاز، هجهز! هذا الفيديو ممتاز، هجهز لك برنامج كامل مع ٣ خيارات للفنادق ونبعثهم على واتساب والايمايل
# تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح
# العفو يا أستاذ جون! استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!

# %%
from extraction_agent.agent import ExtractionAgent
from extraction_agent.models import TranscriptSegment
from datetime import datetime
import time
import json
import uuid
from collections import defaultdict

agent = ExtractionAgent()
results = []
aggregated_entities = defaultdict(list)
total_start = time.time()

# Split text into sentences
corrected = formatted.replace(".", "")
sentences = [s.strip() for s in corrected.split('\n') if s.strip()]

# Process each sentence as a segment
for i, text in enumerate(sentences):
    segment = TranscriptSegment(
        segment_id=f"seg_{i:03d}",
        timestamp=datetime.now(),
        speaker="customer",
        text=text
    )
    extraction = await agent._extract(segment)
    print(extraction)
    entities = extraction.entities or {}
    print(f"\nSegment {i+1}: {text[:50]}...")
    print(f"Entities: {json.dumps(entities, indent=2, ensure_ascii=False)}")
    results.append(entities)

# Aggregate entities from all results
for entities in results:
    if not isinstance(entities, dict) or not entities:
        continue
    for key, value in entities.items():
        if value in (None, "", [], {}):
            continue
        if isinstance(value, list):
            aggregated_entities[key].extend([v for v in value if v not in (None, "", [], {})])
        elif isinstance(value, dict):
            if value:
                aggregated_entities[key].append(value)
        else:
            aggregated_entities[key].append(value)

# De-duplicate while preserving order
for k, v in list(aggregated_entities.items()):
    if isinstance(v, list):
        seen = set()
        deduped = []
        for item in v:
            key_ = json.dumps(item, ensure_ascii=False, sort_keys=True) if isinstance(item, (dict, list)) else str(item)
            if key_ not in seen:
                seen.add(key_)
                deduped.append(item)
        aggregated_entities[k] = deduped

# Sort keys for stable viewing
aggregated_sorted = {k: aggregated_entities[k] for k in sorted(aggregated_entities.keys())}

total_time = (time.time() - total_start) * 1000

print("\n--- Aggregated Entities ---")
print(json.dumps(aggregated_sorted, indent=2, ensure_ascii=False))
print(f"Processed {len(sentences)} segment(s) in {total_time:.0f} ms")
# Out:
# [extractor_0f2be5] Extraction Agent ready
# 2025-12-15 15:24:36,419 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 1666ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_22e902f3' segment_id='seg_000' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 36, 421513) raw_text='مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم المبيعات، ازاي اقدر اساعدك؟ مساء النور يا مريم، انا اسمي جون كارتر' entities={'dates': [], 'budget': {}, 'travelers': {}, 'locations': [], 'activities': [], 'preferences': [], 'keywords': []} processing_time_ms=1666.3212776184082
#
# Segment 1: مساء الخير، شركة جولدن ترال مع حضرتك مريم من قسم ا...
# Entities: {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [],
#   "activities": [],
#   "preferences": [],
#   "keywords": []
# }
# 2025-12-15 15:24:39,850 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 3429ms
#   Found keys: ['dates', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_b03efb65' segment_id='seg_001' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 39, 850939) raw_text='اه الحقيقة انا بفكر ازور مصر! ايه انا بفكر ازور مصر قريب وعايز اعرف شوية تفاصيل، اهلا وسهلا يا أستاذ جون! شرفتنا قول يا حضرتك بتفكر تيجي لوحدك ولا مع حد؟ لا لوحدي، انا ناوي اقعد حوالي خمس ليالي' entities={'dates': ['around five days (5 ليالي)'], 'travelers': {'adults': 1, 'num_of_rooms': 1}, 'locations': ['Egypt (Cairo, Giza, or other popular tourist sites)'], 'activities': ['Plan a solo adventure tour through Egypt’s historical landmarks', 'Explore Cairo’s iconic sites including the Great Pyramids of Giza', 'Visit the Egyptian Museum to learn about ancient artifacts and pharaonic history', 'Discover the ancient temples of Luxor and Karnak', 'Experience the vibrant Khan el-Khalili bazaar for traditional crafts and souvenirs', 'Enjoy cultural experiences like visiting the Egyptian National Museum or the Coptic Cairo district'], 'preferences': ['solo travel', 'cultural and historical exploration', 'moderate pace', 'guided or self-guided tours', 'traditional Egyptian experiences'], 'keywords': ['Egyptian history', 'solo travel', 'ancient monuments', 'Cairo', 'Luxor']} processing_time_ms=3429.143190383911
#
# Segment 2: اه الحقيقة انا بفكر ازور مصر! ايه انا بفكر ازور مص...
# Entities: {
#   "dates": [
#     "around five days (5 ليالي)"
#   ],
#   "travelers": {
#     "adults": 1,
#     "num_of_rooms": 1
#   },
#   "locations": [
#     "Egypt (Cairo, Giza, or other popular tourist sites)"
#   ],
#   "activities": [
#     "Plan a solo adventure tour through Egypt’s historical landmarks",
#     "Explore Cairo’s iconic sites including the Great Pyramids of Giza",
#     "Visit the Egyptian Museum to learn about ancient artifacts and pharaonic history",
#     "Discover the ancient temples of Luxor and Karnak",
#     "Experience the vibrant Khan el-Khalili bazaar for traditional crafts and souvenirs",
#     "Enjoy cultural experiences like visiting the Egyptian National Museum or the Coptic Cairo district"
#   ],
#   "preferences": [
#     "solo travel",
#     "cultural and historical exploration",
#     "moderate pace",
#     "guided or self-guided tours",
#     "traditional Egyptian experiences"
#   ],
#   "keywords": [
#     "Egyptian history",
#     "solo travel",
#     "ancient monuments",
#     "Cairo",
#     "Luxor"
#   ]
# }
# 2025-12-15 15:24:42,084 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 2235ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_1140d583' segment_id='seg_002' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 42, 86359) raw_text='يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر تمام خمس ليالٍ مناسبة جدا بتحب تقضيهم في القاهرة ولا في مدينة تانية؟ بصراحة كنت بفكر في القاهرة كنت بتفكر في القاهرة لأن فيها كل حاجة تقريبا وكمان، يعني أنا مهتم بالنواة لايف شوية' entities={'dates': ['five days (5 ليالٍ)'], 'budget': {}, 'travelers': {}, 'locations': ['Cairo', 'another city'], 'activities': ['Plan a culturally immersive stay in Cairo for five days focusing on local experiences', 'Explore Cairo’s vibrant neighborhoods and iconic landmarks during your visit'], 'preferences': ['short but efficient travel duration', 'urban exploration and local life immersion', 'Cairo-centric itinerary', 'authentic cultural experiences'], 'keywords': ['Cairo city life', 'local experiences', 'urban exploration']} processing_time_ms=2235.1386547088623
#
# Segment 3: يعني مش فترة طويلة بس عايز استغل الوقت كده ما اقدر...
# Entities: {
#   "dates": [
#     "five days (5 ليالٍ)"
#   ],
#   "budget": {},
#   "travelers": {},
#   "locations": [
#     "Cairo",
#     "another city"
#   ],
#   "activities": [
#     "Plan a culturally immersive stay in Cairo for five days focusing on local experiences",
#     "Explore Cairo’s vibrant neighborhoods and iconic landmarks during your visit"
#   ],
#   "preferences": [
#     "short but efficient travel duration",
#     "urban exploration and local life immersion",
#     "Cairo-centric itinerary",
#     "authentic cultural experiences"
#   ],
#   "keywords": [
#     "Cairo city life",
#     "local experiences",
#     "urban exploration"
#   ]
# }
# 2025-12-15 15:24:43,851 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:44,040 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 1766ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_d331312a' segment_id='seg_003' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 43, 852399) raw_text='نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو النوادي اللي الناس بتتكلم عنها' entities={'dates': [], 'budget': {}, 'travelers': {}, 'locations': [], 'activities': ['Explore diverse nightlife venues in Cairo, including cafes and social clubs where locals discuss popular topics', 'Experience lively evening gatherings at trendy cafes or cultural night spots'], 'preferences': ['social experiences', 'local interactions', 'nighttime activities'], 'keywords': ['social nightlife', 'local culture', 'cafes', 'night clubs']} processing_time_ms=1765.6381130218506
#
# Segment 4: نفسي أجرب أماكن مختلفة بالليل، زي الكافيهات أو الن...
# Entities: {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [],
#   "activities": [
#     "Explore diverse nightlife venues in Cairo, including cafes and social clubs where locals discuss popular topics",
#     "Experience lively evening gatherings at trendy cafes or cultural night spots"
#   ],
#   "preferences": [
#     "social experiences",
#     "local interactions",
#     "nighttime activities"
#   ],
#   "keywords": [
#     "social nightlife",
#     "local culture",
#     "cafes",
#     "night clubs"
#   ]
# }
#   ✓ Extracted in 188ms
# extraction_id='ext_4319c6de' segment_id='seg_004' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 44, 41341) raw_text='برضه عايزة ازور أماكن سياحية' entities={} processing_time_ms=188.49921226501465
#
# Segment 5: برضه عايزة ازور أماكن سياحية...
# Entities: {}
# 2025-12-15 15:24:45,502 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 1462ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_dd1700d0' segment_id='seg_005' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 45, 503444) raw_text='وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان القاهرة فعلا غنية بالحاجات دي' entities={'dates': [], 'budget': {}, 'travelers': {}, 'locations': ['القاهرة'], 'activities': ['Explore renowned and highly-rated tourist attractions in Egypt', 'Visit Cairo’s diverse cultural and historical landmarks'], 'preferences': ['high-quality tourist destinations', 'rich cultural experiences'], 'keywords': ['tourist attractions', 'Cairo landmarks', 'cultural heritage']} processing_time_ms=1461.9660377502441
#
# Segment 6: وبرضه عايزة ازور اماكن سياحية مشهورة ممتازة، كمان ...
# Entities: {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [
#     "القاهرة"
#   ],
#   "activities": [
#     "Explore renowned and highly-rated tourist attractions in Egypt",
#     "Visit Cairo’s diverse cultural and historical landmarks"
#   ],
#   "preferences": [
#     "high-quality tourist destinations",
#     "rich cultural experiences"
#   ],
#   "keywords": [
#     "tourist attractions",
#     "Cairo landmarks",
#     "cultural heritage"
#   ]
# }
# 2025-12-15 15:24:47,481 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 1980ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_12ff1ab4' segment_id='seg_006' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 47, 483241) raw_text='ممكن نزور الأهرامات والمتحف المصري وخان الخليلي' entities={'dates': [], 'budget': {}, 'travelers': {}, 'locations': ['Cairo', 'Giza'], 'activities': ['Explore the Great Pyramids of Giza and learn about ancient Egyptian engineering', 'Visit the Egyptian National Museum to discover artifacts from pharaonic history', 'Shop for traditional Egyptian souvenirs and spices at Khan el-Khalili bazaar'], 'preferences': ['cultural heritage exploration', 'historical artifacts', 'local markets'], 'keywords': ['ancient pyramids', 'museum visits', 'Egyptian bazaars']} processing_time_ms=1979.5820713043213
#
# Segment 7: ممكن نزور الأهرامات والمتحف المصري وخان الخليلي...
# Entities: {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [
#     "Cairo",
#     "Giza"
#   ],
#   "activities": [
#     "Explore the Great Pyramids of Giza and learn about ancient Egyptian engineering",
#     "Visit the Egyptian National Museum to discover artifacts from pharaonic history",
#     "Shop for traditional Egyptian souvenirs and spices at Khan el-Khalili bazaar"
#   ],
#   "preferences": [
#     "cultural heritage exploration",
#     "historical artifacts",
#     "local markets"
#   ],
#   "keywords": [
#     "ancient pyramids",
#     "museum visits",
#     "Egyptian bazaars"
#   ]
# }
# 2025-12-15 15:24:52,093 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ❌ TravelPlan validation error: 3 validation errors for TravelPlan
# budget.amount.int
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='moderate', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/int_parsing
# budget.amount.float
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='moderate', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/float_parsing
# travelers.num_of_rooms
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='flexible (implied for group)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/int_parsing
#   ✓ Extracted in 4612ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords', 'tone']
# extraction_id='ext_9b9f97d9' segment_id='seg_007' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 52, 95457) raw_text='كمان نرتبلك خروجات ليلية حلوة على النيل! تحبي يكون البرنامج موزع بين سياحة الصبح ونايت لايف بالليل، اه بالظبط ده اللي انا عايزه يومين سياحة قوية ويومين للنايت لايف، واليوم الخامس ناخليه رايح مثلا جولة نيلية أو حاجة هائلة! جولة نيلية أو حاجة هادئة تمام جدا في ميزانية معينة' entities={'dates': ['two days for sightseeing', 'two days for nightlife', 'fifth day: flexible (Nile cruise or similar)'], 'budget': {'amount': 'moderate', 'flexibility': "somewhat constrained (specific mention of 'ميزانية معينة')"}, 'travelers': {'adults': 1, 'num_of_rooms': 'flexible (implied for group)'}, 'locations': ['Cairo', 'Thebes (Luxor, likely for Nile cruises)', 'Nile River'], 'activities': ['Plan a well-balanced itinerary combining morning sightseeing and evening nightlife activities', 'Spend two days exploring Egypt’s historical sites during the day', 'Enjoy evening entertainment and nightlife experiences in Cairo', 'On the fifth day, choose a relaxing Nile cruise or a culturally immersive experience (e.g., Luxor temples, Karnak)', 'Explore ancient Egyptian landmarks such as Luxor Temple or Karnak Temple during daytime', 'Take a scenic Nile River cruise through Luxor’s historic sites at sunset'], 'preferences': ['balanced itinerary (sightseeing + nightlife)', 'relaxed pace with cultural immersion', 'moderate budget flexibility for activities', 'guided or self-guided Nile cruises', 'authentic Egyptian nightlife experiences'], 'keywords': ['Nile cruises', 'Luxor sightseeing', 'Cairo nightlife', 'Egyptian history', 'relaxing travel'], 'tone': 'enthusiastic and structured (emphasis on planning and variety)'} processing_time_ms=4612.054824829102
#
# Segment 8: كمان نرتبلك خروجات ليلية حلوة على النيل! تحبي يكون...
# Entities: {
#   "dates": [
#     "two days for sightseeing",
#     "two days for nightlife",
#     "fifth day: flexible (Nile cruise or similar)"
#   ],
#   "budget": {
#     "amount": "moderate",
#     "flexibility": "somewhat constrained (specific mention of 'ميزانية معينة')"
#   },
#   "travelers": {
#     "adults": 1,
#     "num_of_rooms": "flexible (implied for group)"
#   },
#   "locations": [
#     "Cairo",
#     "Thebes (Luxor, likely for Nile cruises)",
#     "Nile River"
#   ],
#   "activities": [
#     "Plan a well-balanced itinerary combining morning sightseeing and evening nightlife activities",
#     "Spend two days exploring Egypt’s historical sites during the day",
#     "Enjoy evening entertainment and nightlife experiences in Cairo",
#     "On the fifth day, choose a relaxing Nile cruise or a culturally immersive experience (e.g., Luxor temples, Karnak)",
#     "Explore ancient Egyptian landmarks such as Luxor Temple or Karnak Temple during daytime",
#     "Take a scenic Nile River cruise through Luxor’s historic sites at sunset"
#   ],
#   "preferences": [
#     "balanced itinerary (sightseeing + nightlife)",
#     "relaxed pace with cultural immersion",
#     "moderate budget flexibility for activities",
#     "guided or self-guided Nile cruises",
#     "authentic Egyptian nightlife experiences"
#   ],
#   "keywords": [
#     "Nile cruises",
#     "Luxor sightseeing",
#     "Cairo nightlife",
#     "Egyptian history",
#     "relaxing travel"
#   ],
#   "tone": "enthusiastic and structured (emphasis on planning and variety)"
# }
# 2025-12-15 15:24:53,292 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ❌ TravelPlan validation error: 2 validation errors for TravelPlan
# budget.amount.int
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='unspecified', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/int_parsing
# budget.amount.float
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='unspecified', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/float_parsing
#   ✓ Extracted in 1198ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords', 'tone']
# extraction_id='ext_8e410093' segment_id='seg_008' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 53, 293811) raw_text='حابب نشتغل عليها، يعني متوسط مش عايز حاجة فخمة، أوي بس نظيفة ومرتبة مفهوم' entities={'dates': [], 'budget': {'amount': 'unspecified', 'flexibility': 'moderate'}, 'travelers': {}, 'locations': [], 'activities': [], 'preferences': ['moderate budget accommodations', 'clean and well-organized hotels'], 'keywords': ['comfortable lodging', 'affordable stay'], 'tone': 'neutral, practical'} processing_time_ms=1198.2381343841553
#
# Segment 9: حابب نشتغل عليها، يعني متوسط مش عايز حاجة فخمة، أو...
# Entities: {
#   "dates": [],
#   "budget": {
#     "amount": "unspecified",
#     "flexibility": "moderate"
#   },
#   "travelers": {},
#   "locations": [],
#   "activities": [],
#   "preferences": [
#     "moderate budget accommodations",
#     "clean and well-organized hotels"
#   ],
#   "keywords": [
#     "comfortable lodging",
#     "affordable stay"
#   ],
#   "tone": "neutral, practical"
# }
# 2025-12-15 15:24:54,066 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 773ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_91abc842' segment_id='seg_009' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 54, 67337) raw_text='لو تسمح لي لو تسمح لي اخد رقم حضرتك للتواصل و إرسال البرنامج المقترح، أكيد رقمي هو 1202550198 ممكن تتصلي في أي وقت بعد الظهر؟ تمام سجلته' entities={'dates': [], 'budget': {}, 'travelers': {}, 'locations': [], 'activities': [], 'preferences': [], 'keywords': []} processing_time_ms=773.3719348907471
#
# Segment 10: لو تسمح لي لو تسمح لي اخد رقم حضرتك للتواصل و إرسا...
# Entities: {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [],
#   "activities": [],
#   "preferences": [],
#   "keywords": []
# }
# 2025-12-15 15:24:56,379 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 2025-12-15 15:24:56,522 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 2313ms
#   Found keys: ['dates', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_fc4bb341' segment_id='seg_010' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 56, 380650) raw_text='تمام سجلتِك آخر حاجة، حضرتك جاي في أي وقت تقريبا غالبا في نص الشهر الجاي، لسه ما حددتِش اليوم بالظبط بس هيكون حوالي يوم ١٥ ممتاز، هجهز! هذا الفيديو ممتاز، هجهز لك برنامج كامل مع ٣ خيارات للفنادق ونبعثهم على واتساب والايمايل' entities={'dates': ['نصف شهر مايو', '15 مايو'], 'travelers': {'adults': 1, 'num_of_rooms': 1}, 'locations': ['مصر', 'مصر (غير محدد)'], 'activities': ['Plan and prepare for a flexible travel schedule in Egypt for the upcoming month', 'Explore and enjoy a curated video about Egyptian experiences', 'Book a complete travel program with three hotel options for your trip'], 'preferences': ['flexible arrival time', 'modern amenities', 'digital communication (WhatsApp/email)'], 'keywords': ['flexible travel dates', 'hotel booking options', 'Egyptian travel planning']} processing_time_ms=2313.2128715515137
#
# Segment 11: تمام سجلتِك آخر حاجة، حضرتك جاي في أي وقت تقريبا غ...
# Entities: {
#   "dates": [
#     "نصف شهر مايو",
#     "15 مايو"
#   ],
#   "travelers": {
#     "adults": 1,
#     "num_of_rooms": 1
#   },
#   "locations": [
#     "مصر",
#     "مصر (غير محدد)"
#   ],
#   "activities": [
#     "Plan and prepare for a flexible travel schedule in Egypt for the upcoming month",
#     "Explore and enjoy a curated video about Egyptian experiences",
#     "Book a complete travel program with three hotel options for your trip"
#   ],
#   "preferences": [
#     "flexible arrival time",
#     "modern amenities",
#     "digital communication (WhatsApp/email)"
#   ],
#   "keywords": [
#     "flexible travel dates",
#     "hotel booking options",
#     "Egyptian travel planning"
#   ]
# }
#   ✓ Extracted in 142ms
# extraction_id='ext_91f8df6c' segment_id='seg_011' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 56, 523067) raw_text='تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح' entities={} processing_time_ms=142.24886894226074
#
# Segment 12: تمام يا مريم! شكرا لك جدا، حقيقي شرح كل حاجة بوضوح...
# Entities: {}
# 2025-12-15 15:24:57,325 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
#   ✓ Extracted in 803ms
#   Found keys: ['dates', 'budget', 'travelers', 'locations', 'activities', 'preferences', 'keywords']
# extraction_id='ext_58979758' segment_id='seg_012' timestamp=datetime.datetime(2025, 12, 15, 15, 24, 57, 326481) raw_text='العفو يا أستاذ جون! استاذ جون، ده واجبنا نتشرف بزيارتك لمصر اليوم جميل وأنتي كمان مع السلامة!' entities={'dates': [], 'budget': {}, 'travelers': {}, 'locations': ['مصر'], 'activities': [], 'preferences': [], 'keywords': []} processing_time_ms=803.3430576324463
#
# Segment 13: العفو يا أستاذ جون! استاذ جون، ده واجبنا نتشرف بزي...
# Entities: {
#   "dates": [],
#   "budget": {},
#   "travelers": {},
#   "locations": [
#     "مصر"
#   ],
#   "activities": [],
#   "preferences": [],
#   "keywords": []
# }
#
# --- Aggregated Entities ---
# {
#   "activities": [
#     "Plan a solo adventure tour through Egypt’s historical landmarks",
#     "Explore Cairo’s iconic sites including the Great Pyramids of Giza",
#     "Visit the Egyptian Museum to learn about ancient artifacts and pharaonic history",
#     "Discover the ancient temples of Luxor and Karnak",
#     "Experience the vibrant Khan el-Khalili bazaar for traditional crafts and souvenirs",
#     "Enjoy cultural experiences like visiting the Egyptian National Museum or the Coptic Cairo district",
#     "Plan a culturally immersive stay in Cairo for five days focusing on local experiences",
#     "Explore Cairo’s vibrant neighborhoods and iconic landmarks during your visit",
#     "Explore diverse nightlife venues in Cairo, including cafes and social clubs where locals discuss popular topics",
#     "Experience lively evening gatherings at trendy cafes or cultural night spots",
#     "Explore renowned and highly-rated tourist attractions in Egypt",
#     "Visit Cairo’s diverse cultural and historical landmarks",
#     "Explore the Great Pyramids of Giza and learn about ancient Egyptian engineering",
#     "Visit the Egyptian National Museum to discover artifacts from pharaonic history",
#     "Shop for traditional Egyptian souvenirs and spices at Khan el-Khalili bazaar",
#     "Plan a well-balanced itinerary combining morning sightseeing and evening nightlife activities",
#     "Spend two days exploring Egypt’s historical sites during the day",
#     "Enjoy evening entertainment and nightlife experiences in Cairo",
#     "On the fifth day, choose a relaxing Nile cruise or a culturally immersive experience (e.g., Luxor temples, Karnak)",
#     "Explore ancient Egyptian landmarks such as Luxor Temple or Karnak Temple during daytime",
#     "Take a scenic Nile River cruise through Luxor’s historic sites at sunset",
#     "Plan and prepare for a flexible travel schedule in Egypt for the upcoming month",
#     "Explore and enjoy a curated video about Egyptian experiences",
#     "Book a complete travel program with three hotel options for your trip"
#   ],
#   "budget": [
#     {
#       "amount": "moderate",
#       "flexibility": "somewhat constrained (specific mention of 'ميزانية معينة')"
#     },
#     {
#       "amount": "unspecified",
#       "flexibility": "moderate"
#     }
#   ],
#   "dates": [
#     "around five days (5 ليالي)",
#     "five days (5 ليالٍ)",
#     "two days for sightseeing",
#     "two days for nightlife",
#     "fifth day: flexible (Nile cruise or similar)",
#     "نصف شهر مايو",
#     "15 مايو"
#   ],
#   "keywords": [
#     "Egyptian history",
#     "solo travel",
#     "ancient monuments",
#     "Cairo",
#     "Luxor",
#     "Cairo city life",
#     "local experiences",
#     "urban exploration",
#     "social nightlife",
#     "local culture",
#     "cafes",
#     "night clubs",
#     "tourist attractions",
#     "Cairo landmarks",
#     "cultural heritage",
#     "ancient pyramids",
#     "museum visits",
#     "Egyptian bazaars",
#     "Nile cruises",
#     "Luxor sightseeing",
#     "Cairo nightlife",
#     "relaxing travel",
#     "comfortable lodging",
#     "affordable stay",
#     "flexible travel dates",
#     "hotel booking options",
#     "Egyptian travel planning"
#   ],
#   "locations": [
#     "Egypt (Cairo, Giza, or other popular tourist sites)",
#     "Cairo",
#     "another city",
#     "القاهرة",
#     "Giza",
#     "Thebes (Luxor, likely for Nile cruises)",
#     "Nile River",
#     "مصر",
#     "مصر (غير محدد)"
#   ],
#   "preferences": [
#     "solo travel",
#     "cultural and historical exploration",
#     "moderate pace",
#     "guided or self-guided tours",
#     "traditional Egyptian experiences",
#     "short but efficient travel duration",
#     "urban exploration and local life immersion",
#     "Cairo-centric itinerary",
#     "authentic cultural experiences",
#     "social experiences",
#     "local interactions",
#     "nighttime activities",
#     "high-quality tourist destinations",
#     "rich cultural experiences",
#     "cultural heritage exploration",
#     "historical artifacts",
#     "local markets",
#     "balanced itinerary (sightseeing + nightlife)",
#     "relaxed pace with cultural immersion",
#     "moderate budget flexibility for activities",
#     "guided or self-guided Nile cruises",
#     "authentic Egyptian nightlife experiences",
#     "moderate budget accommodations",
#     "clean and well-organized hotels",
#     "flexible arrival time",
#     "modern amenities",
#     "digital communication (WhatsApp/email)"
#   ],
#   "tone": [
#     "enthusiastic and structured (emphasis on planning and variety)",
#     "neutral, practical"
#   ],
#   "travelers": [
#     {
#       "adults": 1,
#       "num_of_rooms": 1
#     },
#     {
#       "adults": 1,
#       "num_of_rooms": "flexible (implied for group)"
#     }
#   ]
# }
# Processed 13 segment(s) in 22572 ms
